# %% [markdown]
# <a href="https://colab.research.google.com/github/suhitaghosh10/unet/blob/master/unet_gn_wn_wdsc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import numpy as np
import os

from keras import backend as K
K.set_image_data_format('channels_last')  # TF dimension ordering in this code

from weight_norm import AdamWithWeightnorm 
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau, EarlyStopping, TensorBoard

from keras.models import Model
from keras.layers import concatenate, Input, Conv3D, MaxPooling3D, Conv3DTranspose, Lambda, Dropout
from keras.callbacks import CSVLogger
#from keras.utils.vis_utils import plot_model

smooth = 1.

class anisotopic_UNET:

    def get_Tversky(alpha=.3, beta=.7, verb=0):
        def Tversky(y_true, y_pred):
            y_true_f = K.flatten(y_true)
            y_pred_f = K.flatten(y_pred)
            intersection = K.sum(y_true_f * y_pred_f)
            G_P = alpha * K.sum((1 - y_true_f) * y_pred_f)  # G not P
            P_G = beta * K.sum(y_true_f * (1 - y_pred_f))  # P not G
            return (intersection + smooth) / (intersection + smooth + G_P + P_G)

        def Tversky_loss(y_true, y_pred):
            return -Tversky(y_true, y_pred)

        return Tversky, Tversky_loss

    # Tversky, Tversky_loss = get_Tversky(alpha = .3,beta= .7,verb=0)
    # Metrics = [dice_coef_loss ,Tversky

      
    def dice_coefficient(self, y_true, y_pred, axis=(-4, -3, -2), smooth=0.00001):
          return K.mean(2. * (K.sum(y_true * y_pred,
                              axis=axis) + smooth/2)/(K.sum(y_true,
                                                            axis=axis) + K.sum(y_pred,
                                                                               axis=axis) + smooth))
      
    def W_dice_coefficient(self, y_true, y_pred, smooth=0.00001):
          return K.mean(2. * (K.sum(y_true * y_pred) + smooth/2)/(K.sum(y_true,) + K.sum(y_pred) + smooth))
                                                                               


    def dice_coefficient_loss(self, y_true, y_pred):
         return -self.dice_coefficient(y_true, y_pred)
      
    def W_dice_coefficient_loss(self, y_true, y_pred):
         return -self.W_dice_coefficient(y_true, y_pred)
 

    # downsampling, analysis path
    def downLayer(self, inputLayer, filterSize, i, bn=False):

        conv = Conv3D(filterSize, (3, 3, 3), activation='relu', padding='same',  name='conv'+str(i)+'_1')(inputLayer)
        if bn:
            conv = GroupNormalization(groups=8, axis=1)(conv)
        conv = Conv3D(filterSize * 2, (3, 3, 3), activation='relu', padding='same',  name='conv'+str(i)+'_2')(conv)
        if bn:
            conv = GroupNormalization(groups=8, axis=1)(conv)
        pool = MaxPooling3D(pool_size=(1, 2, 2))(conv)

        return pool, conv


    # upsampling, synthesis path
    def upLayer(self, inputLayer, concatLayer, filterSize, i, bn=False, do= False):

        up = Conv3DTranspose(filterSize, (2, 2, 2), strides=(1, 2, 2), activation='relu', padding='same',  name='up'+str(i))(inputLayer)
       # print( concatLayer.shape)
        up = concatenate([up, concatLayer])
        conv = Conv3D(int(filterSize/2), (3, 3, 3), activation='relu', padding='same',  name='conv'+str(i)+'_1')(up)
        if bn:
            conv = GroupNormalization(groups=8, axis=1)(conv)
        if do:
            conv = Dropout(0.5, seed = 3, name='Dropout_' + str(i))(conv)
        conv = Conv3D(int(filterSize/2), (3, 3, 3), activation='relu', padding='same',  name='conv'+str(i)+'_2')(conv)
        if bn:
            conv = GroupNormalization(groups=8, axis=1)(conv)

        return conv



    """
    TODO: 
    correct position of batch normalization. instead of using it after relu activation, place it between
    convolutions and activation function
    """

    def get_net(self, nrInputChannels=1, learningRate=5e-5, bn = True, do = False):

        sfs = 16  # start filter size

        inputs = Input((32, 168, 168, nrInputChannels))

        conv1, conv1_b_m = self.downLayer(inputs, sfs, 1, bn)
        conv2, conv2_b_m = self.downLayer(conv1, sfs * 2, 2, bn)

        conv3 = Conv3D(sfs * 4, (3, 3, 3), activation='relu', padding='same', name='conv' + str(3) + '_1')(conv2)
        if bn:
            conv3 = GroupNormalization(groups=8, axis=1)(conv3)
        conv3 = Conv3D(sfs * 8, (3, 3, 3), activation='relu', padding='same', name='conv' + str(3) + '_2')(conv3)
        if bn:
            conv3 = GroupNormalization(groups=8, axis=1)(conv3)
        pool3 = MaxPooling3D(pool_size=(2, 2, 2))(conv3)
        # conv3, conv3_b_m = downLayer(conv2, sfs*4, 3, bn)

        conv4 = Conv3D(sfs * 16, (3, 3, 3), activation='relu', padding='same', name='conv4_1')(pool3)
        if bn:
            conv4 = GroupNormalization(groups=8, axis=1)(conv4)
        if do:
            conv4 = Dropout(0.5, seed=4, name='Dropout_' + str(4))(conv4)
        conv4 = Conv3D(sfs * 16, (3, 3, 3), activation='relu', padding='same', name='conv4_2')(conv4)
        if bn:
            conv4 = GroupNormalization(groups=8, axis=1)(conv4)

        # conv5 = upLayer(conv4, conv3_b_m, sfs*16, 5, bn, do)
        up1 = Conv3DTranspose(sfs * 16, (2, 2, 2), strides=(2, 2, 2), activation='relu', padding='same',
                              name='up' + str(5))(conv4)
        up1 = concatenate([up1, conv3])
        conv5 = Conv3D(int(sfs * 8), (3, 3, 3), activation='relu', padding='same', name='conv' + str(5) + '_1')(up1)
        if bn:
            conv5 = GroupNormalization(groups=8, axis=1)(conv5)
        if do:
            conv5 = Dropout(0.5, seed=5, name='Dropout_' + str(5))(conv5)
        conv5 = Conv3D(int(sfs * 8), (3, 3, 3), activation='relu', padding='same', name='conv' + str(5) + '_2')(conv5)
        if bn:
            conv5 = GroupNormalization(groups=8, axis=1)(conv5)

        conv6 = self.upLayer(conv5, conv2_b_m, sfs * 8, 6, bn, do)
        conv7 = self.upLayer(conv6, conv1_b_m, sfs * 4, 7, bn, do)

        conv_out = Conv3D(5, (1, 1, 1), activation='softmax', name='conv_final_softmax')(conv7)

        pz = Lambda(lambda x: x[:, :, :, :, 0], name='pz')(conv_out)
        cz = Lambda(lambda x: x[:, :, :, :, 1], name='cz')(conv_out)
        us = Lambda(lambda x: x[:, :, :, :, 2], name='us')(conv_out)
        afs = Lambda(lambda x: x[:, :, :, :, 3], name='afs')(conv_out)
        bg = Lambda(lambda x: x[:, :, :, :, 4], name='bg')(conv_out)

        model = Model(inputs=[inputs], outputs=[pz, cz, us, afs, bg])
        model.compile(optimizer=AdamWithWeightnorm(lr=learningRate, beta_1=0.9, beta_2=0.999),
                      loss={'pz': self.dice_coefficient_loss, 'cz': self.dice_coefficient_loss, 'us': self.dice_coefficient_loss,
                            'afs': self.dice_coefficient_loss, 'bg': self.dice_coefficient_loss},
                      
                      metrics={'pz': self.dice_coefficient, 'cz': self.dice_coefficient, 'us': self.dice_coefficient,
                               'afs': self.dice_coefficient, 'bg': self.dice_coefficient})
        
        return model

# %%
def train_model(epochs, learningRate, imgs, gt_list, val_imgs, val_gt_list, foldNr):

      name = 'UNet_zones_Fold' + str(foldNr) + '_LR_' + str(learningRate)

    # keras callbacks
      csv_logger = CSVLogger(name+'.csv', append=True, separator=';')
      model_checkpoint = ModelCheckpoint(name+'.h5', monitor='val_loss', save_best_only=True, verbose=1, mode='min')
      earlyStopImprovement = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=100, verbose=1, mode='min')
      LRDecay = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=25, verbose=1, mode='min', min_lr=1e-8,
                                epsilon=0.01)
      tensorboard = TensorBoard(log_dir='./zonal2_tensorboard_logs/', write_graph=False, write_grads=False, histogram_freq=0,
                              batch_size=5,
                              write_images=False)

      print('-' * 30)
      print('Creating and compiling model...')
      print('-' * 30)

      network = anisotopic_UNET()
      model = network.get_net(learningRate = LR, bn = True, do=True)
    # plot_model(model, to_file='model.png')

      print('-' * 30)
      print('Fitting model...')
      print('-' * 30)

      cb = [csv_logger, model_checkpoint, earlyStopImprovement, LRDecay]

      print('Callbacks: ', cb)

      history = model.fit(imgs, gt_list, batch_size=2, epochs=epochs,
                        verbose=1, validation_data=[val_imgs, val_gt_list], shuffle=True, callbacks=cb)
      model.save(name + '_final.h5')

      return history

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
from group_norm import GroupNormalization
if __name__ == '__main__':

    """
    TODO: 
    correct position of batch normalization. instead of using it after relu activation, place it between
    convolutions and activation function
    """

    #os.environ["CUDA_VISIBLE_DEVICES"] = str(sys.argv[3])
    #os.environ["CUDA_VISIBLE_DEVICES"] = '0'


    epochs = 400    #sys.argv[1]
    LR = 5e-4       #sys.argv[2]
    foldNr = 1      #sys.argv[4]
    '''
    #val_imgs = np.load('final_test_array_imgs.npy')
    val_imgs = np.load('image_npy_orig4.npy')
    print(val_imgs.shape)
    #val_gt = np.load('/home/suhita/zonals/data/test/image_npy_gt.npy')
    val_gt = np.load('image_npy_gt4.npy')

    print(val_gt.shape)
    val_gt = val_gt.astype(np.uint8)
    val_gt_list = [val_gt[:, :, :, :, 0], val_gt[:, :, :, :, 1], val_gt[:, :, :, :, 2], val_gt[:, :, :, :, 3],
                   val_gt[:, :, :, :, 4]]
    predict(val_imgs, val_gt_list, 'model.h5')
'''
    # load validation images and GT 
    val_imgs = np.load('drive/My Drive/prostrate/valArray_imgs_fold'+str(foldNr)+'.npy')
    print(val_imgs.shape)
    val_gt = np.load('drive/My Drive/prostrate/valArray_GT_fold'+str(foldNr)+'.npy')
    print(val_gt.shape)
    val_gt = val_gt.astype(np.uint8)
    val_gt_list = [val_gt[:, :, :, :, 0], val_gt[:, :, :, :, 1], val_gt[:, :, :, :, 2], val_gt[:, :, :, :, 3],
                   val_gt[:, :, :, :, 4]]

    # load train images and GT
    train_imgs = np.load(
        'drive/My Drive/prostrate/trainArray_imgs_fold' + str(foldNr) + '.npy')
    train_imgs_red = train_imgs[0:30,:,:,:,:]
    print(train_imgs_red.shape)
    train_gt = np.load(
        'drive/My Drive/prostrate/trainArray_GT_fold' + str(foldNr) + '.npy')
    train_gt = train_gt.astype(np.uint8)
    train_gt_red = train_gt[0:30,:,:,:,:]
    print(train_gt_red.shape)
    
    #train_gt_list_red = [train_gt_red[:, :, :, :, 0], train_gt_red[:, :, :, :, 1], train_gt_red[:, :, :, :, 2], train_gt_red[:, :, :, :, 3],
     #                train_gt_red[:, :, :, :, 4]]
    
    train_gt_list = [train_gt[:, :, :, :, 0], train_gt[:, :, :, :, 1], train_gt[:, :, :, :, 2], train_gt[:, :, :, :, 3],
                     train_gt[:, :, :, :, 4]]
    
    train_model(epochs, LR, train_imgs, train_gt_list, val_imgs, val_gt_list, foldNr)
# Out:
# (20, 32, 168, 168, 1)
# (20, 32, 168, 168, 5)
# (30, 32, 168, 168, 1)
# (30, 32, 168, 168, 5)
# ------------------------------
# Creating and compiling model...
# ------------------------------
# /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1065: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '
# ------------------------------
# Fitting model...
# ------------------------------
# Callbacks:  [<keras.callbacks.CSVLogger object at 0x7fdacdcf8f28>, <keras.callbacks.ModelCheckpoint object at 0x7fdacdcf8940>, <keras.callbacks.EarlyStopping object at 0x7fdad1e876a0>, <keras.callbacks.ReduceLROnPlateau object at 0x7fdad1f277f0>]
# Train on 58 samples, validate on 20 samples
# Epoch 1/400
# 58/58 [==============================] - 83s 1s/step - loss: -1.1293 - pz_loss: -0.0632 - cz_loss: -0.1922 - us_loss: -0.0028 - afs_loss: -0.0073 - bg_loss: -0.8638 - pz_dice_coefficient: 0.0632 - cz_dice_coefficient: 0.1922 - us_dice_coefficient: 0.0028 - afs_dice_coefficient: 0.0073 - bg_dice_coefficient: 0.8638 - val_loss: -1.2848 - val_pz_loss: -0.1273 - val_cz_loss: -0.2829 - val_us_loss: -0.0016 - val_afs_loss: -0.0070 - val_bg_loss: -0.8661 - val_pz_dice_coefficient: 0.1273 - val_cz_dice_coefficient: 0.2829 - val_us_dice_coefficient: 0.0016 - val_afs_dice_coefficient: 0.0070 - val_bg_dice_coefficient: 0.8661
#
# Epoch 00001: val_loss improved from inf to -1.28483, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 2/400
# 58/58 [==============================] - 77s 1s/step - loss: -1.4889 - pz_loss: -0.1640 - cz_loss: -0.3766 - us_loss: -0.0019 - afs_loss: -0.0126 - bg_loss: -0.9338 - pz_dice_coefficient: 0.1640 - cz_dice_coefficient: 0.3766 - us_dice_coefficient: 0.0019 - afs_dice_coefficient: 0.0126 - bg_dice_coefficient: 0.9338 - val_loss: -1.6094 - val_pz_loss: -0.2449 - val_cz_loss: -0.3838 - val_us_loss: -0.0015 - val_afs_loss: -0.0159 - val_bg_loss: -0.9633 - val_pz_dice_coefficient: 0.2449 - val_cz_dice_coefficient: 0.3838 - val_us_dice_coefficient: 0.0015 - val_afs_dice_coefficient: 0.0159 - val_bg_dice_coefficient: 0.9633
#
# Epoch 00002: val_loss improved from -1.28483 to -1.60942, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 3/400
# 58/58 [==============================] - 77s 1s/step - loss: -1.6133 - pz_loss: -0.2332 - cz_loss: -0.4019 - us_loss: -0.0021 - afs_loss: -0.0273 - bg_loss: -0.9487 - pz_dice_coefficient: 0.2332 - cz_dice_coefficient: 0.4019 - us_dice_coefficient: 0.0021 - afs_dice_coefficient: 0.0273 - bg_dice_coefficient: 0.9487 - val_loss: -1.7204 - val_pz_loss: -0.2779 - val_cz_loss: -0.4220 - val_us_loss: -0.0024 - val_afs_loss: -0.0508 - val_bg_loss: -0.9673 - val_pz_dice_coefficient: 0.2779 - val_cz_dice_coefficient: 0.4220 - val_us_dice_coefficient: 0.0024 - val_afs_dice_coefficient: 0.0508 - val_bg_dice_coefficient: 0.9673
#
# Epoch 00003: val_loss improved from -1.60942 to -1.72040, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 4/400
# 58/58 [==============================] - 77s 1s/step - loss: -1.7866 - pz_loss: -0.3057 - cz_loss: -0.4349 - us_loss: -0.0033 - afs_loss: -0.0752 - bg_loss: -0.9675 - pz_dice_coefficient: 0.3057 - cz_dice_coefficient: 0.4349 - us_dice_coefficient: 0.0033 - afs_dice_coefficient: 0.0752 - bg_dice_coefficient: 0.9675 - val_loss: -1.8211 - val_pz_loss: -0.3445 - val_cz_loss: -0.4396 - val_us_loss: -0.0033 - val_afs_loss: -0.0671 - val_bg_loss: -0.9667 - val_pz_dice_coefficient: 0.3445 - val_cz_dice_coefficient: 0.4396 - val_us_dice_coefficient: 0.0033 - val_afs_dice_coefficient: 0.0671 - val_bg_dice_coefficient: 0.9667
#
# Epoch 00004: val_loss improved from -1.72040 to -1.82111, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 5/400
# 58/58 [==============================] - 77s 1s/step - loss: -1.8744 - pz_loss: -0.3493 - cz_loss: -0.4461 - us_loss: -0.0032 - afs_loss: -0.1049 - bg_loss: -0.9708 - pz_dice_coefficient: 0.3493 - cz_dice_coefficient: 0.4461 - us_dice_coefficient: 0.0032 - afs_dice_coefficient: 0.1049 - bg_dice_coefficient: 0.9708 - val_loss: -1.9394 - val_pz_loss: -0.3840 - val_cz_loss: -0.4650 - val_us_loss: -0.0047 - val_afs_loss: -0.1074 - val_bg_loss: -0.9784 - val_pz_dice_coefficient: 0.3840 - val_cz_dice_coefficient: 0.4650 - val_us_dice_coefficient: 0.0047 - val_afs_dice_coefficient: 0.1074 - val_bg_dice_coefficient: 0.9784
#
# Epoch 00005: val_loss improved from -1.82111 to -1.93943, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 6/400
# 58/58 [==============================] - 77s 1s/step - loss: -1.9276 - pz_loss: -0.3645 - cz_loss: -0.4531 - us_loss: -0.0053 - afs_loss: -0.1286 - bg_loss: -0.9761 - pz_dice_coefficient: 0.3645 - cz_dice_coefficient: 0.4531 - us_dice_coefficient: 0.0053 - afs_dice_coefficient: 0.1286 - bg_dice_coefficient: 0.9761 - val_loss: -1.9440 - val_pz_loss: -0.3899 - val_cz_loss: -0.4546 - val_us_loss: -0.0074 - val_afs_loss: -0.1151 - val_bg_loss: -0.9770 - val_pz_dice_coefficient: 0.3899 - val_cz_dice_coefficient: 0.4546 - val_us_dice_coefficient: 0.0074 - val_afs_dice_coefficient: 0.1151 - val_bg_dice_coefficient: 0.9770
#
# Epoch 00006: val_loss improved from -1.93943 to -1.94402, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 7/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.0247 - pz_loss: -0.3917 - cz_loss: -0.4851 - us_loss: -0.0113 - afs_loss: -0.1578 - bg_loss: -0.9789 - pz_dice_coefficient: 0.3917 - cz_dice_coefficient: 0.4851 - us_dice_coefficient: 0.0113 - afs_dice_coefficient: 0.1578 - bg_dice_coefficient: 0.9789 - val_loss: -2.0076 - val_pz_loss: -0.3987 - val_cz_loss: -0.4683 - val_us_loss: -0.0164 - val_afs_loss: -0.1452 - val_bg_loss: -0.9789 - val_pz_dice_coefficient: 0.3987 - val_cz_dice_coefficient: 0.4683 - val_us_dice_coefficient: 0.0164 - val_afs_dice_coefficient: 0.1452 - val_bg_dice_coefficient: 0.9789
#
# Epoch 00007: val_loss improved from -1.94402 to -2.00761, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 8/400
# 58/58 [==============================] - 77s 1s/step - loss: -2.0269 - pz_loss: -0.3987 - cz_loss: -0.4833 - us_loss: -0.0191 - afs_loss: -0.1464 - bg_loss: -0.9794 - pz_dice_coefficient: 0.3987 - cz_dice_coefficient: 0.4833 - us_dice_coefficient: 0.0191 - afs_dice_coefficient: 0.1464 - bg_dice_coefficient: 0.9794 - val_loss: -2.0407 - val_pz_loss: -0.4128 - val_cz_loss: -0.4722 - val_us_loss: -0.0286 - val_afs_loss: -0.1479 - val_bg_loss: -0.9793 - val_pz_dice_coefficient: 0.4128 - val_cz_dice_coefficient: 0.4722 - val_us_dice_coefficient: 0.0286 - val_afs_dice_coefficient: 0.1479 - val_bg_dice_coefficient: 0.9793
#
# Epoch 00008: val_loss improved from -2.00761 to -2.04074, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 9/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.0809 - pz_loss: -0.4116 - cz_loss: -0.4985 - us_loss: -0.0252 - afs_loss: -0.1660 - bg_loss: -0.9797 - pz_dice_coefficient: 0.4116 - cz_dice_coefficient: 0.4985 - us_dice_coefficient: 0.0252 - afs_dice_coefficient: 0.1660 - bg_dice_coefficient: 0.9797 - val_loss: -2.0895 - val_pz_loss: -0.4362 - val_cz_loss: -0.4859 - val_us_loss: -0.0297 - val_afs_loss: -0.1574 - val_bg_loss: -0.9803 - val_pz_dice_coefficient: 0.4362 - val_cz_dice_coefficient: 0.4859 - val_us_dice_coefficient: 0.0297 - val_afs_dice_coefficient: 0.1574 - val_bg_dice_coefficient: 0.9803
#
# Epoch 00009: val_loss improved from -2.04074 to -2.08948, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 10/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.1404 - pz_loss: -0.4412 - cz_loss: -0.5106 - us_loss: -0.0308 - afs_loss: -0.1746 - bg_loss: -0.9831 - pz_dice_coefficient: 0.4412 - cz_dice_coefficient: 0.5106 - us_dice_coefficient: 0.0308 - afs_dice_coefficient: 0.1746 - bg_dice_coefficient: 0.9831 - val_loss: -2.1140 - val_pz_loss: -0.4576 - val_cz_loss: -0.4867 - val_us_loss: -0.0318 - val_afs_loss: -0.1560 - val_bg_loss: -0.9819 - val_pz_dice_coefficient: 0.4576 - val_cz_dice_coefficient: 0.4867 - val_us_dice_coefficient: 0.0318 - val_afs_dice_coefficient: 0.1560 - val_bg_dice_coefficient: 0.9819
#
# Epoch 00010: val_loss improved from -2.08948 to -2.11401, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 11/400
# 58/58 [==============================] - 77s 1s/step - loss: -2.2005 - pz_loss: -0.4592 - cz_loss: -0.5275 - us_loss: -0.0323 - afs_loss: -0.1977 - bg_loss: -0.9837 - pz_dice_coefficient: 0.4592 - cz_dice_coefficient: 0.5275 - us_dice_coefficient: 0.0323 - afs_dice_coefficient: 0.1977 - bg_dice_coefficient: 0.9837 - val_loss: -2.1297 - val_pz_loss: -0.4586 - val_cz_loss: -0.4837 - val_us_loss: -0.0365 - val_afs_loss: -0.1706 - val_bg_loss: -0.9803 - val_pz_dice_coefficient: 0.4586 - val_cz_dice_coefficient: 0.4837 - val_us_dice_coefficient: 0.0365 - val_afs_dice_coefficient: 0.1706 - val_bg_dice_coefficient: 0.9803
#
# Epoch 00011: val_loss improved from -2.11401 to -2.12967, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 12/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.1434 - pz_loss: -0.4402 - cz_loss: -0.5046 - us_loss: -0.0339 - afs_loss: -0.1813 - bg_loss: -0.9835 - pz_dice_coefficient: 0.4402 - cz_dice_coefficient: 0.5046 - us_dice_coefficient: 0.0339 - afs_dice_coefficient: 0.1813 - bg_dice_coefficient: 0.9835 - val_loss: -2.1111 - val_pz_loss: -0.4624 - val_cz_loss: -0.4683 - val_us_loss: -0.0224 - val_afs_loss: -0.1756 - val_bg_loss: -0.9824 - val_pz_dice_coefficient: 0.4624 - val_cz_dice_coefficient: 0.4683 - val_us_dice_coefficient: 0.0224 - val_afs_dice_coefficient: 0.1756 - val_bg_dice_coefficient: 0.9824
#
# Epoch 00012: val_loss did not improve from -2.12967
# Epoch 13/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.1811 - pz_loss: -0.4596 - cz_loss: -0.5108 - us_loss: -0.0383 - afs_loss: -0.1881 - bg_loss: -0.9844 - pz_dice_coefficient: 0.4596 - cz_dice_coefficient: 0.5108 - us_dice_coefficient: 0.0383 - afs_dice_coefficient: 0.1881 - bg_dice_coefficient: 0.9844 - val_loss: -2.1529 - val_pz_loss: -0.4626 - val_cz_loss: -0.4968 - val_us_loss: -0.0450 - val_afs_loss: -0.1658 - val_bg_loss: -0.9828 - val_pz_dice_coefficient: 0.4626 - val_cz_dice_coefficient: 0.4968 - val_us_dice_coefficient: 0.0450 - val_afs_dice_coefficient: 0.1658 - val_bg_dice_coefficient: 0.9828
#
# Epoch 00013: val_loss improved from -2.12967 to -2.15293, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 14/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.2100 - pz_loss: -0.4678 - cz_loss: -0.5212 - us_loss: -0.0434 - afs_loss: -0.1924 - bg_loss: -0.9851 - pz_dice_coefficient: 0.4678 - cz_dice_coefficient: 0.5212 - us_dice_coefficient: 0.0434 - afs_dice_coefficient: 0.1924 - bg_dice_coefficient: 0.9851 - val_loss: -2.1348 - val_pz_loss: -0.4638 - val_cz_loss: -0.4766 - val_us_loss: -0.0441 - val_afs_loss: -0.1662 - val_bg_loss: -0.9842 - val_pz_dice_coefficient: 0.4638 - val_cz_dice_coefficient: 0.4766 - val_us_dice_coefficient: 0.0441 - val_afs_dice_coefficient: 0.1662 - val_bg_dice_coefficient: 0.9842
#
# Epoch 00014: val_loss did not improve from -2.15293
# Epoch 15/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.2493 - pz_loss: -0.4827 - cz_loss: -0.5360 - us_loss: -0.0445 - afs_loss: -0.1997 - bg_loss: -0.9863 - pz_dice_coefficient: 0.4827 - cz_dice_coefficient: 0.5360 - us_dice_coefficient: 0.0445 - afs_dice_coefficient: 0.1997 - bg_dice_coefficient: 0.9863 - val_loss: -2.1559 - val_pz_loss: -0.4661 - val_cz_loss: -0.4921 - val_us_loss: -0.0484 - val_afs_loss: -0.1676 - val_bg_loss: -0.9818 - val_pz_dice_coefficient: 0.4661 - val_cz_dice_coefficient: 0.4921 - val_us_dice_coefficient: 0.0484 - val_afs_dice_coefficient: 0.1676 - val_bg_dice_coefficient: 0.9818
#
# Epoch 00015: val_loss improved from -2.15293 to -2.15587, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 16/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.2251 - pz_loss: -0.4749 - cz_loss: -0.5101 - us_loss: -0.0488 - afs_loss: -0.2058 - bg_loss: -0.9857 - pz_dice_coefficient: 0.4749 - cz_dice_coefficient: 0.5101 - us_dice_coefficient: 0.0488 - afs_dice_coefficient: 0.2058 - bg_dice_coefficient: 0.9857 - val_loss: -2.1686 - val_pz_loss: -0.4813 - val_cz_loss: -0.4808 - val_us_loss: -0.0520 - val_afs_loss: -0.1700 - val_bg_loss: -0.9844 - val_pz_dice_coefficient: 0.4813 - val_cz_dice_coefficient: 0.4808 - val_us_dice_coefficient: 0.0520 - val_afs_dice_coefficient: 0.1700 - val_bg_dice_coefficient: 0.9844
#
# Epoch 00016: val_loss improved from -2.15587 to -2.16861, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 17/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.2741 - pz_loss: -0.4933 - cz_loss: -0.5341 - us_loss: -0.0546 - afs_loss: -0.2048 - bg_loss: -0.9873 - pz_dice_coefficient: 0.4933 - cz_dice_coefficient: 0.5341 - us_dice_coefficient: 0.0546 - afs_dice_coefficient: 0.2048 - bg_dice_coefficient: 0.9873 - val_loss: -2.1789 - val_pz_loss: -0.4730 - val_cz_loss: -0.4967 - val_us_loss: -0.0480 - val_afs_loss: -0.1753 - val_bg_loss: -0.9859 - val_pz_dice_coefficient: 0.4730 - val_cz_dice_coefficient: 0.4967 - val_us_dice_coefficient: 0.0480 - val_afs_dice_coefficient: 0.1753 - val_bg_dice_coefficient: 0.9859
#
# Epoch 00017: val_loss improved from -2.16861 to -2.17886, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 18/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.2690 - pz_loss: -0.4901 - cz_loss: -0.5304 - us_loss: -0.0569 - afs_loss: -0.2045 - bg_loss: -0.9872 - pz_dice_coefficient: 0.4901 - cz_dice_coefficient: 0.5304 - us_dice_coefficient: 0.0569 - afs_dice_coefficient: 0.2045 - bg_dice_coefficient: 0.9872 - val_loss: -2.1746 - val_pz_loss: -0.4461 - val_cz_loss: -0.5007 - val_us_loss: -0.0696 - val_afs_loss: -0.1724 - val_bg_loss: -0.9858 - val_pz_dice_coefficient: 0.4461 - val_cz_dice_coefficient: 0.5007 - val_us_dice_coefficient: 0.0696 - val_afs_dice_coefficient: 0.1724 - val_bg_dice_coefficient: 0.9858
#
# Epoch 00018: val_loss did not improve from -2.17886
# Epoch 19/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.2868 - pz_loss: -0.4919 - cz_loss: -0.5356 - us_loss: -0.0597 - afs_loss: -0.2122 - bg_loss: -0.9873 - pz_dice_coefficient: 0.4919 - cz_dice_coefficient: 0.5356 - us_dice_coefficient: 0.0597 - afs_dice_coefficient: 0.2122 - bg_dice_coefficient: 0.9873 - val_loss: -2.1642 - val_pz_loss: -0.4632 - val_cz_loss: -0.4850 - val_us_loss: -0.0700 - val_afs_loss: -0.1629 - val_bg_loss: -0.9830 - val_pz_dice_coefficient: 0.4632 - val_cz_dice_coefficient: 0.4850 - val_us_dice_coefficient: 0.0700 - val_afs_dice_coefficient: 0.1629 - val_bg_dice_coefficient: 0.9830
#
# Epoch 00019: val_loss did not improve from -2.17886
# Epoch 20/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.2500 - pz_loss: -0.4812 - cz_loss: -0.5210 - us_loss: -0.0574 - afs_loss: -0.2037 - bg_loss: -0.9867 - pz_dice_coefficient: 0.4812 - cz_dice_coefficient: 0.5210 - us_dice_coefficient: 0.0574 - afs_dice_coefficient: 0.2037 - bg_dice_coefficient: 0.9867 - val_loss: -2.1933 - val_pz_loss: -0.4791 - val_cz_loss: -0.4909 - val_us_loss: -0.0616 - val_afs_loss: -0.1770 - val_bg_loss: -0.9847 - val_pz_dice_coefficient: 0.4791 - val_cz_dice_coefficient: 0.4909 - val_us_dice_coefficient: 0.0616 - val_afs_dice_coefficient: 0.1770 - val_bg_dice_coefficient: 0.9847
#
# Epoch 00020: val_loss improved from -2.17886 to -2.19330, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 21/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.2993 - pz_loss: -0.4938 - cz_loss: -0.5360 - us_loss: -0.0655 - afs_loss: -0.2169 - bg_loss: -0.9872 - pz_dice_coefficient: 0.4938 - cz_dice_coefficient: 0.5360 - us_dice_coefficient: 0.0655 - afs_dice_coefficient: 0.2169 - bg_dice_coefficient: 0.9872 - val_loss: -2.2081 - val_pz_loss: -0.4767 - val_cz_loss: -0.5016 - val_us_loss: -0.0741 - val_afs_loss: -0.1702 - val_bg_loss: -0.9854 - val_pz_dice_coefficient: 0.4767 - val_cz_dice_coefficient: 0.5016 - val_us_dice_coefficient: 0.0741 - val_afs_dice_coefficient: 0.1702 - val_bg_dice_coefficient: 0.9854
#
# Epoch 00021: val_loss improved from -2.19330 to -2.20811, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 22/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.3176 - pz_loss: -0.5026 - cz_loss: -0.5390 - us_loss: -0.0669 - afs_loss: -0.2208 - bg_loss: -0.9882 - pz_dice_coefficient: 0.5026 - cz_dice_coefficient: 0.5390 - us_dice_coefficient: 0.0669 - afs_dice_coefficient: 0.2208 - bg_dice_coefficient: 0.9882 - val_loss: -2.2476 - val_pz_loss: -0.4982 - val_cz_loss: -0.5077 - val_us_loss: -0.0773 - val_afs_loss: -0.1788 - val_bg_loss: -0.9856 - val_pz_dice_coefficient: 0.4982 - val_cz_dice_coefficient: 0.5077 - val_us_dice_coefficient: 0.0773 - val_afs_dice_coefficient: 0.1788 - val_bg_dice_coefficient: 0.9856
#
# Epoch 00022: val_loss improved from -2.20811 to -2.24763, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 23/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.3546 - pz_loss: -0.5209 - cz_loss: -0.5534 - us_loss: -0.0705 - afs_loss: -0.2210 - bg_loss: -0.9888 - pz_dice_coefficient: 0.5209 - cz_dice_coefficient: 0.5534 - us_dice_coefficient: 0.0705 - afs_dice_coefficient: 0.2210 - bg_dice_coefficient: 0.9888 - val_loss: -2.2250 - val_pz_loss: -0.4984 - val_cz_loss: -0.4902 - val_us_loss: -0.0824 - val_afs_loss: -0.1673 - val_bg_loss: -0.9867 - val_pz_dice_coefficient: 0.4984 - val_cz_dice_coefficient: 0.4902 - val_us_dice_coefficient: 0.0824 - val_afs_dice_coefficient: 0.1673 - val_bg_dice_coefficient: 0.9867
#
# Epoch 00023: val_loss did not improve from -2.24763
# Epoch 24/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.3464 - pz_loss: -0.5197 - cz_loss: -0.5418 - us_loss: -0.0730 - afs_loss: -0.2228 - bg_loss: -0.9892 - pz_dice_coefficient: 0.5197 - cz_dice_coefficient: 0.5418 - us_dice_coefficient: 0.0730 - afs_dice_coefficient: 0.2228 - bg_dice_coefficient: 0.9892 - val_loss: -2.2587 - val_pz_loss: -0.5117 - val_cz_loss: -0.5096 - val_us_loss: -0.0780 - val_afs_loss: -0.1732 - val_bg_loss: -0.9862 - val_pz_dice_coefficient: 0.5117 - val_cz_dice_coefficient: 0.5096 - val_us_dice_coefficient: 0.0780 - val_afs_dice_coefficient: 0.1732 - val_bg_dice_coefficient: 0.9862
#
# Epoch 00024: val_loss improved from -2.24763 to -2.25865, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 25/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.3550 - pz_loss: -0.5226 - cz_loss: -0.5403 - us_loss: -0.0750 - afs_loss: -0.2279 - bg_loss: -0.9892 - pz_dice_coefficient: 0.5226 - cz_dice_coefficient: 0.5403 - us_dice_coefficient: 0.0750 - afs_dice_coefficient: 0.2279 - bg_dice_coefficient: 0.9892 - val_loss: -2.2611 - val_pz_loss: -0.5095 - val_cz_loss: -0.5114 - val_us_loss: -0.0796 - val_afs_loss: -0.1751 - val_bg_loss: -0.9855 - val_pz_dice_coefficient: 0.5095 - val_cz_dice_coefficient: 0.5114 - val_us_dice_coefficient: 0.0796 - val_afs_dice_coefficient: 0.1751 - val_bg_dice_coefficient: 0.9855
#
# Epoch 00025: val_loss improved from -2.25865 to -2.26106, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 26/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.3698 - pz_loss: -0.5229 - cz_loss: -0.5464 - us_loss: -0.0817 - afs_loss: -0.2296 - bg_loss: -0.9892 - pz_dice_coefficient: 0.5229 - cz_dice_coefficient: 0.5464 - us_dice_coefficient: 0.0817 - afs_dice_coefficient: 0.2296 - bg_dice_coefficient: 0.9892 - val_loss: -2.2651 - val_pz_loss: -0.5125 - val_cz_loss: -0.5070 - val_us_loss: -0.0810 - val_afs_loss: -0.1787 - val_bg_loss: -0.9860 - val_pz_dice_coefficient: 0.5125 - val_cz_dice_coefficient: 0.5070 - val_us_dice_coefficient: 0.0810 - val_afs_dice_coefficient: 0.1787 - val_bg_dice_coefficient: 0.9860
#
# Epoch 00026: val_loss improved from -2.26106 to -2.26509, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 27/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.3727 - pz_loss: -0.5315 - cz_loss: -0.5473 - us_loss: -0.0812 - afs_loss: -0.2231 - bg_loss: -0.9897 - pz_dice_coefficient: 0.5315 - cz_dice_coefficient: 0.5473 - us_dice_coefficient: 0.0812 - afs_dice_coefficient: 0.2231 - bg_dice_coefficient: 0.9897 - val_loss: -2.2618 - val_pz_loss: -0.5007 - val_cz_loss: -0.5116 - val_us_loss: -0.0853 - val_afs_loss: -0.1778 - val_bg_loss: -0.9864 - val_pz_dice_coefficient: 0.5007 - val_cz_dice_coefficient: 0.5116 - val_us_dice_coefficient: 0.0853 - val_afs_dice_coefficient: 0.1778 - val_bg_dice_coefficient: 0.9864
#
# Epoch 00027: val_loss did not improve from -2.26509
# Epoch 28/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.3791 - pz_loss: -0.5307 - cz_loss: -0.5509 - us_loss: -0.0806 - afs_loss: -0.2270 - bg_loss: -0.9898 - pz_dice_coefficient: 0.5307 - cz_dice_coefficient: 0.5509 - us_dice_coefficient: 0.0806 - afs_dice_coefficient: 0.2270 - bg_dice_coefficient: 0.9898 - val_loss: -2.2453 - val_pz_loss: -0.4971 - val_cz_loss: -0.5043 - val_us_loss: -0.0803 - val_afs_loss: -0.1768 - val_bg_loss: -0.9868 - val_pz_dice_coefficient: 0.4971 - val_cz_dice_coefficient: 0.5043 - val_us_dice_coefficient: 0.0803 - val_afs_dice_coefficient: 0.1768 - val_bg_dice_coefficient: 0.9868
#
# Epoch 00028: val_loss did not improve from -2.26509
# Epoch 29/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.3795 - pz_loss: -0.5308 - cz_loss: -0.5495 - us_loss: -0.0815 - afs_loss: -0.2280 - bg_loss: -0.9898 - pz_dice_coefficient: 0.5308 - cz_dice_coefficient: 0.5495 - us_dice_coefficient: 0.0815 - afs_dice_coefficient: 0.2280 - bg_dice_coefficient: 0.9898 - val_loss: -2.2659 - val_pz_loss: -0.5143 - val_cz_loss: -0.5058 - val_us_loss: -0.0854 - val_afs_loss: -0.1734 - val_bg_loss: -0.9871 - val_pz_dice_coefficient: 0.5143 - val_cz_dice_coefficient: 0.5058 - val_us_dice_coefficient: 0.0854 - val_afs_dice_coefficient: 0.1734 - val_bg_dice_coefficient: 0.9871
#
# Epoch 00029: val_loss improved from -2.26509 to -2.26593, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 30/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.4159 - pz_loss: -0.5370 - cz_loss: -0.5647 - us_loss: -0.0806 - afs_loss: -0.2438 - bg_loss: -0.9897 - pz_dice_coefficient: 0.5370 - cz_dice_coefficient: 0.5647 - us_dice_coefficient: 0.0806 - afs_dice_coefficient: 0.2438 - bg_dice_coefficient: 0.9897 - val_loss: -2.2691 - val_pz_loss: -0.5186 - val_cz_loss: -0.5078 - val_us_loss: -0.0880 - val_afs_loss: -0.1677 - val_bg_loss: -0.9870 - val_pz_dice_coefficient: 0.5186 - val_cz_dice_coefficient: 0.5078 - val_us_dice_coefficient: 0.0880 - val_afs_dice_coefficient: 0.1677 - val_bg_dice_coefficient: 0.9870
#
# Epoch 00030: val_loss improved from -2.26593 to -2.26907, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 31/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.3882 - pz_loss: -0.5303 - cz_loss: -0.5455 - us_loss: -0.0822 - afs_loss: -0.2399 - bg_loss: -0.9903 - pz_dice_coefficient: 0.5303 - cz_dice_coefficient: 0.5455 - us_dice_coefficient: 0.0822 - afs_dice_coefficient: 0.2399 - bg_dice_coefficient: 0.9903 - val_loss: -2.2545 - val_pz_loss: -0.5035 - val_cz_loss: -0.5056 - val_us_loss: -0.0827 - val_afs_loss: -0.1763 - val_bg_loss: -0.9864 - val_pz_dice_coefficient: 0.5035 - val_cz_dice_coefficient: 0.5056 - val_us_dice_coefficient: 0.0827 - val_afs_dice_coefficient: 0.1763 - val_bg_dice_coefficient: 0.9864
#
# Epoch 00031: val_loss did not improve from -2.26907
# Epoch 32/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.4009 - pz_loss: -0.5346 - cz_loss: -0.5520 - us_loss: -0.0877 - afs_loss: -0.2367 - bg_loss: -0.9899 - pz_dice_coefficient: 0.5346 - cz_dice_coefficient: 0.5520 - us_dice_coefficient: 0.0877 - afs_dice_coefficient: 0.2367 - bg_dice_coefficient: 0.9899 - val_loss: -2.2643 - val_pz_loss: -0.5030 - val_cz_loss: -0.5130 - val_us_loss: -0.0876 - val_afs_loss: -0.1744 - val_bg_loss: -0.9864 - val_pz_dice_coefficient: 0.5030 - val_cz_dice_coefficient: 0.5130 - val_us_dice_coefficient: 0.0876 - val_afs_dice_coefficient: 0.1744 - val_bg_dice_coefficient: 0.9864
#
# Epoch 00032: val_loss did not improve from -2.26907
# Epoch 33/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.4096 - pz_loss: -0.5431 - cz_loss: -0.5549 - us_loss: -0.0856 - afs_loss: -0.2355 - bg_loss: -0.9904 - pz_dice_coefficient: 0.5431 - cz_dice_coefficient: 0.5549 - us_dice_coefficient: 0.0856 - afs_dice_coefficient: 0.2355 - bg_dice_coefficient: 0.9904 - val_loss: -2.2796 - val_pz_loss: -0.5182 - val_cz_loss: -0.5073 - val_us_loss: -0.0833 - val_afs_loss: -0.1839 - val_bg_loss: -0.9869 - val_pz_dice_coefficient: 0.5182 - val_cz_dice_coefficient: 0.5073 - val_us_dice_coefficient: 0.0833 - val_afs_dice_coefficient: 0.1839 - val_bg_dice_coefficient: 0.9869
#
# Epoch 00033: val_loss improved from -2.26907 to -2.27958, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 34/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.4176 - pz_loss: -0.5343 - cz_loss: -0.5589 - us_loss: -0.0895 - afs_loss: -0.2448 - bg_loss: -0.9900 - pz_dice_coefficient: 0.5343 - cz_dice_coefficient: 0.5589 - us_dice_coefficient: 0.0895 - afs_dice_coefficient: 0.2448 - bg_dice_coefficient: 0.9900 - val_loss: -2.2590 - val_pz_loss: -0.5024 - val_cz_loss: -0.5081 - val_us_loss: -0.0888 - val_afs_loss: -0.1728 - val_bg_loss: -0.9868 - val_pz_dice_coefficient: 0.5024 - val_cz_dice_coefficient: 0.5081 - val_us_dice_coefficient: 0.0888 - val_afs_dice_coefficient: 0.1728 - val_bg_dice_coefficient: 0.9868
#
# Epoch 00034: val_loss did not improve from -2.27958
# Epoch 35/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.4152 - pz_loss: -0.5414 - cz_loss: -0.5572 - us_loss: -0.0880 - afs_loss: -0.2383 - bg_loss: -0.9903 - pz_dice_coefficient: 0.5414 - cz_dice_coefficient: 0.5572 - us_dice_coefficient: 0.0880 - afs_dice_coefficient: 0.2383 - bg_dice_coefficient: 0.9903 - val_loss: -2.2635 - val_pz_loss: -0.5033 - val_cz_loss: -0.5096 - val_us_loss: -0.0865 - val_afs_loss: -0.1783 - val_bg_loss: -0.9859 - val_pz_dice_coefficient: 0.5033 - val_cz_dice_coefficient: 0.5096 - val_us_dice_coefficient: 0.0865 - val_afs_dice_coefficient: 0.1783 - val_bg_dice_coefficient: 0.9859
#
# Epoch 00035: val_loss did not improve from -2.27958
# Epoch 36/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.4156 - pz_loss: -0.5403 - cz_loss: -0.5559 - us_loss: -0.0854 - afs_loss: -0.2440 - bg_loss: -0.9900 - pz_dice_coefficient: 0.5403 - cz_dice_coefficient: 0.5559 - us_dice_coefficient: 0.0854 - afs_dice_coefficient: 0.2440 - bg_dice_coefficient: 0.9900 - val_loss: -2.2502 - val_pz_loss: -0.4975 - val_cz_loss: -0.5081 - val_us_loss: -0.0779 - val_afs_loss: -0.1796 - val_bg_loss: -0.9871 - val_pz_dice_coefficient: 0.4975 - val_cz_dice_coefficient: 0.5081 - val_us_dice_coefficient: 0.0779 - val_afs_dice_coefficient: 0.1796 - val_bg_dice_coefficient: 0.9871
#
# Epoch 00036: val_loss did not improve from -2.27958
# Epoch 37/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.4312 - pz_loss: -0.5453 - cz_loss: -0.5529 - us_loss: -0.0882 - afs_loss: -0.2545 - bg_loss: -0.9904 - pz_dice_coefficient: 0.5453 - cz_dice_coefficient: 0.5529 - us_dice_coefficient: 0.0882 - afs_dice_coefficient: 0.2545 - bg_dice_coefficient: 0.9904 - val_loss: -2.2385 - val_pz_loss: -0.5006 - val_cz_loss: -0.5123 - val_us_loss: -0.0848 - val_afs_loss: -0.1541 - val_bg_loss: -0.9867 - val_pz_dice_coefficient: 0.5006 - val_cz_dice_coefficient: 0.5123 - val_us_dice_coefficient: 0.0848 - val_afs_dice_coefficient: 0.1541 - val_bg_dice_coefficient: 0.9867
#
# Epoch 00037: val_loss did not improve from -2.27958
# Epoch 38/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.4249 - pz_loss: -0.5395 - cz_loss: -0.5544 - us_loss: -0.0885 - afs_loss: -0.2520 - bg_loss: -0.9905 - pz_dice_coefficient: 0.5395 - cz_dice_coefficient: 0.5544 - us_dice_coefficient: 0.0885 - afs_dice_coefficient: 0.2520 - bg_dice_coefficient: 0.9905 - val_loss: -2.2662 - val_pz_loss: -0.5050 - val_cz_loss: -0.5140 - val_us_loss: -0.0911 - val_afs_loss: -0.1702 - val_bg_loss: -0.9859 - val_pz_dice_coefficient: 0.5050 - val_cz_dice_coefficient: 0.5140 - val_us_dice_coefficient: 0.0911 - val_afs_dice_coefficient: 0.1702 - val_bg_dice_coefficient: 0.9859
#
# Epoch 00038: val_loss did not improve from -2.27958
# Epoch 39/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.4183 - pz_loss: -0.5382 - cz_loss: -0.5531 - us_loss: -0.0883 - afs_loss: -0.2490 - bg_loss: -0.9897 - pz_dice_coefficient: 0.5382 - cz_dice_coefficient: 0.5531 - us_dice_coefficient: 0.0883 - afs_dice_coefficient: 0.2490 - bg_dice_coefficient: 0.9897 - val_loss: -2.2487 - val_pz_loss: -0.5001 - val_cz_loss: -0.5073 - val_us_loss: -0.0900 - val_afs_loss: -0.1671 - val_bg_loss: -0.9842 - val_pz_dice_coefficient: 0.5001 - val_cz_dice_coefficient: 0.5073 - val_us_dice_coefficient: 0.0900 - val_afs_dice_coefficient: 0.1671 - val_bg_dice_coefficient: 0.9842
#
# Epoch 00039: val_loss did not improve from -2.27958
# Epoch 40/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.4322 - pz_loss: -0.5452 - cz_loss: -0.5618 - us_loss: -0.0859 - afs_loss: -0.2489 - bg_loss: -0.9905 - pz_dice_coefficient: 0.5452 - cz_dice_coefficient: 0.5618 - us_dice_coefficient: 0.0859 - afs_dice_coefficient: 0.2489 - bg_dice_coefficient: 0.9905 - val_loss: -2.2716 - val_pz_loss: -0.5144 - val_cz_loss: -0.5028 - val_us_loss: -0.0880 - val_afs_loss: -0.1789 - val_bg_loss: -0.9874 - val_pz_dice_coefficient: 0.5144 - val_cz_dice_coefficient: 0.5028 - val_us_dice_coefficient: 0.0880 - val_afs_dice_coefficient: 0.1789 - val_bg_dice_coefficient: 0.9874
#
# Epoch 00040: val_loss did not improve from -2.27958
# Epoch 41/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.4416 - pz_loss: -0.5442 - cz_loss: -0.5653 - us_loss: -0.0894 - afs_loss: -0.2518 - bg_loss: -0.9908 - pz_dice_coefficient: 0.5442 - cz_dice_coefficient: 0.5653 - us_dice_coefficient: 0.0894 - afs_dice_coefficient: 0.2518 - bg_dice_coefficient: 0.9908 - val_loss: -2.2597 - val_pz_loss: -0.5018 - val_cz_loss: -0.5149 - val_us_loss: -0.0778 - val_afs_loss: -0.1776 - val_bg_loss: -0.9876 - val_pz_dice_coefficient: 0.5018 - val_cz_dice_coefficient: 0.5149 - val_us_dice_coefficient: 0.0778 - val_afs_dice_coefficient: 0.1776 - val_bg_dice_coefficient: 0.9876
#
# Epoch 00041: val_loss did not improve from -2.27958
# Epoch 42/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.4393 - pz_loss: -0.5518 - cz_loss: -0.5477 - us_loss: -0.0922 - afs_loss: -0.2565 - bg_loss: -0.9911 - pz_dice_coefficient: 0.5518 - cz_dice_coefficient: 0.5477 - us_dice_coefficient: 0.0922 - afs_dice_coefficient: 0.2565 - bg_dice_coefficient: 0.9911 - val_loss: -2.2709 - val_pz_loss: -0.5028 - val_cz_loss: -0.5150 - val_us_loss: -0.0914 - val_afs_loss: -0.1739 - val_bg_loss: -0.9878 - val_pz_dice_coefficient: 0.5028 - val_cz_dice_coefficient: 0.5150 - val_us_dice_coefficient: 0.0914 - val_afs_dice_coefficient: 0.1739 - val_bg_dice_coefficient: 0.9878
#
# Epoch 00042: val_loss did not improve from -2.27958
# Epoch 43/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.4730 - pz_loss: -0.5547 - cz_loss: -0.5702 - us_loss: -0.0948 - afs_loss: -0.2621 - bg_loss: -0.9913 - pz_dice_coefficient: 0.5547 - cz_dice_coefficient: 0.5702 - us_dice_coefficient: 0.0948 - afs_dice_coefficient: 0.2621 - bg_dice_coefficient: 0.9913 - val_loss: -2.2505 - val_pz_loss: -0.5103 - val_cz_loss: -0.5132 - val_us_loss: -0.0855 - val_afs_loss: -0.1545 - val_bg_loss: -0.9868 - val_pz_dice_coefficient: 0.5103 - val_cz_dice_coefficient: 0.5132 - val_us_dice_coefficient: 0.0855 - val_afs_dice_coefficient: 0.1545 - val_bg_dice_coefficient: 0.9868
#
# Epoch 00043: val_loss did not improve from -2.27958
# Epoch 44/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.4409 - pz_loss: -0.5476 - cz_loss: -0.5535 - us_loss: -0.0968 - afs_loss: -0.2519 - bg_loss: -0.9911 - pz_dice_coefficient: 0.5476 - cz_dice_coefficient: 0.5535 - us_dice_coefficient: 0.0968 - afs_dice_coefficient: 0.2519 - bg_dice_coefficient: 0.9911 - val_loss: -2.2776 - val_pz_loss: -0.5148 - val_cz_loss: -0.5058 - val_us_loss: -0.0892 - val_afs_loss: -0.1803 - val_bg_loss: -0.9876 - val_pz_dice_coefficient: 0.5148 - val_cz_dice_coefficient: 0.5058 - val_us_dice_coefficient: 0.0892 - val_afs_dice_coefficient: 0.1803 - val_bg_dice_coefficient: 0.9876
#
# Epoch 00044: val_loss did not improve from -2.27958
# Epoch 45/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.4607 - pz_loss: -0.5543 - cz_loss: -0.5542 - us_loss: -0.0914 - afs_loss: -0.2700 - bg_loss: -0.9908 - pz_dice_coefficient: 0.5543 - cz_dice_coefficient: 0.5542 - us_dice_coefficient: 0.0914 - afs_dice_coefficient: 0.2700 - bg_dice_coefficient: 0.9908 - val_loss: -2.2474 - val_pz_loss: -0.5041 - val_cz_loss: -0.5094 - val_us_loss: -0.0870 - val_afs_loss: -0.1601 - val_bg_loss: -0.9867 - val_pz_dice_coefficient: 0.5041 - val_cz_dice_coefficient: 0.5094 - val_us_dice_coefficient: 0.0870 - val_afs_dice_coefficient: 0.1601 - val_bg_dice_coefficient: 0.9867
#
# Epoch 00045: val_loss did not improve from -2.27958
# Epoch 46/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.4638 - pz_loss: -0.5590 - cz_loss: -0.5632 - us_loss: -0.0896 - afs_loss: -0.2606 - bg_loss: -0.9914 - pz_dice_coefficient: 0.5590 - cz_dice_coefficient: 0.5632 - us_dice_coefficient: 0.0896 - afs_dice_coefficient: 0.2606 - bg_dice_coefficient: 0.9914 - val_loss: -2.2675 - val_pz_loss: -0.5030 - val_cz_loss: -0.5072 - val_us_loss: -0.0874 - val_afs_loss: -0.1819 - val_bg_loss: -0.9880 - val_pz_dice_coefficient: 0.5030 - val_cz_dice_coefficient: 0.5072 - val_us_dice_coefficient: 0.0874 - val_afs_dice_coefficient: 0.1819 - val_bg_dice_coefficient: 0.9880
#
# Epoch 00046: val_loss did not improve from -2.27958
# Epoch 47/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.4772 - pz_loss: -0.5547 - cz_loss: -0.5616 - us_loss: -0.0939 - afs_loss: -0.2761 - bg_loss: -0.9911 - pz_dice_coefficient: 0.5547 - cz_dice_coefficient: 0.5616 - us_dice_coefficient: 0.0939 - afs_dice_coefficient: 0.2761 - bg_dice_coefficient: 0.9911 - val_loss: -2.2886 - val_pz_loss: -0.5201 - val_cz_loss: -0.5148 - val_us_loss: -0.0937 - val_afs_loss: -0.1731 - val_bg_loss: -0.9868 - val_pz_dice_coefficient: 0.5201 - val_cz_dice_coefficient: 0.5148 - val_us_dice_coefficient: 0.0937 - val_afs_dice_coefficient: 0.1731 - val_bg_dice_coefficient: 0.9868
#
# Epoch 00047: val_loss improved from -2.27958 to -2.28864, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 48/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.4997 - pz_loss: -0.5608 - cz_loss: -0.5814 - us_loss: -0.0921 - afs_loss: -0.2739 - bg_loss: -0.9915 - pz_dice_coefficient: 0.5608 - cz_dice_coefficient: 0.5814 - us_dice_coefficient: 0.0921 - afs_dice_coefficient: 0.2739 - bg_dice_coefficient: 0.9915 - val_loss: -2.2836 - val_pz_loss: -0.5147 - val_cz_loss: -0.5174 - val_us_loss: -0.0908 - val_afs_loss: -0.1729 - val_bg_loss: -0.9876 - val_pz_dice_coefficient: 0.5147 - val_cz_dice_coefficient: 0.5174 - val_us_dice_coefficient: 0.0908 - val_afs_dice_coefficient: 0.1729 - val_bg_dice_coefficient: 0.9876
#
# Epoch 00048: val_loss did not improve from -2.28864
# Epoch 49/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.4968 - pz_loss: -0.5612 - cz_loss: -0.5779 - us_loss: -0.0952 - afs_loss: -0.2711 - bg_loss: -0.9914 - pz_dice_coefficient: 0.5612 - cz_dice_coefficient: 0.5779 - us_dice_coefficient: 0.0952 - afs_dice_coefficient: 0.2711 - bg_dice_coefficient: 0.9914 - val_loss: -2.2167 - val_pz_loss: -0.4950 - val_cz_loss: -0.5064 - val_us_loss: -0.0896 - val_afs_loss: -0.1414 - val_bg_loss: -0.9843 - val_pz_dice_coefficient: 0.4950 - val_cz_dice_coefficient: 0.5064 - val_us_dice_coefficient: 0.0896 - val_afs_dice_coefficient: 0.1414 - val_bg_dice_coefficient: 0.9843
#
# Epoch 00049: val_loss did not improve from -2.28864
# Epoch 50/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.4354 - pz_loss: -0.5331 - cz_loss: -0.5548 - us_loss: -0.0926 - afs_loss: -0.2650 - bg_loss: -0.9899 - pz_dice_coefficient: 0.5331 - cz_dice_coefficient: 0.5548 - us_dice_coefficient: 0.0926 - afs_dice_coefficient: 0.2650 - bg_dice_coefficient: 0.9899 - val_loss: -2.1730 - val_pz_loss: -0.4561 - val_cz_loss: -0.4944 - val_us_loss: -0.0855 - val_afs_loss: -0.1535 - val_bg_loss: -0.9834 - val_pz_dice_coefficient: 0.4561 - val_cz_dice_coefficient: 0.4944 - val_us_dice_coefficient: 0.0855 - val_afs_dice_coefficient: 0.1535 - val_bg_dice_coefficient: 0.9834
#
# Epoch 00050: val_loss did not improve from -2.28864
# Epoch 51/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.4192 - pz_loss: -0.5408 - cz_loss: -0.5494 - us_loss: -0.0872 - afs_loss: -0.2515 - bg_loss: -0.9903 - pz_dice_coefficient: 0.5408 - cz_dice_coefficient: 0.5494 - us_dice_coefficient: 0.0872 - afs_dice_coefficient: 0.2515 - bg_dice_coefficient: 0.9903 - val_loss: -2.2693 - val_pz_loss: -0.5022 - val_cz_loss: -0.5075 - val_us_loss: -0.0900 - val_afs_loss: -0.1837 - val_bg_loss: -0.9860 - val_pz_dice_coefficient: 0.5022 - val_cz_dice_coefficient: 0.5075 - val_us_dice_coefficient: 0.0900 - val_afs_dice_coefficient: 0.1837 - val_bg_dice_coefficient: 0.9860
#
# Epoch 00051: val_loss did not improve from -2.28864
# Epoch 52/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.4833 - pz_loss: -0.5579 - cz_loss: -0.5648 - us_loss: -0.0952 - afs_loss: -0.2741 - bg_loss: -0.9912 - pz_dice_coefficient: 0.5579 - cz_dice_coefficient: 0.5648 - us_dice_coefficient: 0.0952 - afs_dice_coefficient: 0.2741 - bg_dice_coefficient: 0.9912 - val_loss: -2.2798 - val_pz_loss: -0.5155 - val_cz_loss: -0.5149 - val_us_loss: -0.0912 - val_afs_loss: -0.1703 - val_bg_loss: -0.9879 - val_pz_dice_coefficient: 0.5155 - val_cz_dice_coefficient: 0.5149 - val_us_dice_coefficient: 0.0912 - val_afs_dice_coefficient: 0.1703 - val_bg_dice_coefficient: 0.9879
#
# Epoch 00052: val_loss did not improve from -2.28864
# Epoch 53/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.4915 - pz_loss: -0.5595 - cz_loss: -0.5605 - us_loss: -0.0981 - afs_loss: -0.2819 - bg_loss: -0.9915 - pz_dice_coefficient: 0.5595 - cz_dice_coefficient: 0.5605 - us_dice_coefficient: 0.0981 - afs_dice_coefficient: 0.2819 - bg_dice_coefficient: 0.9915 - val_loss: -2.2977 - val_pz_loss: -0.5219 - val_cz_loss: -0.5198 - val_us_loss: -0.0924 - val_afs_loss: -0.1750 - val_bg_loss: -0.9886 - val_pz_dice_coefficient: 0.5219 - val_cz_dice_coefficient: 0.5198 - val_us_dice_coefficient: 0.0924 - val_afs_dice_coefficient: 0.1750 - val_bg_dice_coefficient: 0.9886
#
# Epoch 00053: val_loss improved from -2.28864 to -2.29769, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 54/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.5055 - pz_loss: -0.5622 - cz_loss: -0.5828 - us_loss: -0.0960 - afs_loss: -0.2730 - bg_loss: -0.9915 - pz_dice_coefficient: 0.5622 - cz_dice_coefficient: 0.5828 - us_dice_coefficient: 0.0960 - afs_dice_coefficient: 0.2730 - bg_dice_coefficient: 0.9915 - val_loss: -2.2863 - val_pz_loss: -0.5234 - val_cz_loss: -0.5166 - val_us_loss: -0.0915 - val_afs_loss: -0.1664 - val_bg_loss: -0.9883 - val_pz_dice_coefficient: 0.5234 - val_cz_dice_coefficient: 0.5166 - val_us_dice_coefficient: 0.0915 - val_afs_dice_coefficient: 0.1664 - val_bg_dice_coefficient: 0.9883
#
# Epoch 00054: val_loss did not improve from -2.29769
# Epoch 55/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.5256 - pz_loss: -0.5688 - cz_loss: -0.5734 - us_loss: -0.0982 - afs_loss: -0.2934 - bg_loss: -0.9919 - pz_dice_coefficient: 0.5688 - cz_dice_coefficient: 0.5734 - us_dice_coefficient: 0.0982 - afs_dice_coefficient: 0.2934 - bg_dice_coefficient: 0.9919 - val_loss: -2.2903 - val_pz_loss: -0.5305 - val_cz_loss: -0.5165 - val_us_loss: -0.0842 - val_afs_loss: -0.1704 - val_bg_loss: -0.9886 - val_pz_dice_coefficient: 0.5305 - val_cz_dice_coefficient: 0.5165 - val_us_dice_coefficient: 0.0842 - val_afs_dice_coefficient: 0.1704 - val_bg_dice_coefficient: 0.9886
#
# Epoch 00055: val_loss did not improve from -2.29769
# Epoch 56/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.5180 - pz_loss: -0.5687 - cz_loss: -0.5730 - us_loss: -0.0955 - afs_loss: -0.2886 - bg_loss: -0.9922 - pz_dice_coefficient: 0.5687 - cz_dice_coefficient: 0.5730 - us_dice_coefficient: 0.0955 - afs_dice_coefficient: 0.2886 - bg_dice_coefficient: 0.9922 - val_loss: -2.2792 - val_pz_loss: -0.5198 - val_cz_loss: -0.5108 - val_us_loss: -0.0943 - val_afs_loss: -0.1669 - val_bg_loss: -0.9874 - val_pz_dice_coefficient: 0.5198 - val_cz_dice_coefficient: 0.5108 - val_us_dice_coefficient: 0.0943 - val_afs_dice_coefficient: 0.1669 - val_bg_dice_coefficient: 0.9874
#
# Epoch 00056: val_loss did not improve from -2.29769
# Epoch 57/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.4976 - pz_loss: -0.5649 - cz_loss: -0.5619 - us_loss: -0.0994 - afs_loss: -0.2797 - bg_loss: -0.9919 - pz_dice_coefficient: 0.5649 - cz_dice_coefficient: 0.5619 - us_dice_coefficient: 0.0994 - afs_dice_coefficient: 0.2797 - bg_dice_coefficient: 0.9919 - val_loss: -2.3019 - val_pz_loss: -0.5294 - val_cz_loss: -0.5065 - val_us_loss: -0.0911 - val_afs_loss: -0.1867 - val_bg_loss: -0.9881 - val_pz_dice_coefficient: 0.5294 - val_cz_dice_coefficient: 0.5065 - val_us_dice_coefficient: 0.0911 - val_afs_dice_coefficient: 0.1867 - val_bg_dice_coefficient: 0.9881
#
# Epoch 00057: val_loss improved from -2.29769 to -2.30185, saving model to UNet_zones_Fold1_LR_0.0005.h5
# Epoch 58/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.5382 - pz_loss: -0.5759 - cz_loss: -0.5716 - us_loss: -0.0952 - afs_loss: -0.3031 - bg_loss: -0.9923 - pz_dice_coefficient: 0.5759 - cz_dice_coefficient: 0.5716 - us_dice_coefficient: 0.0952 - afs_dice_coefficient: 0.3031 - bg_dice_coefficient: 0.9923 - val_loss: -2.2997 - val_pz_loss: -0.5277 - val_cz_loss: -0.5185 - val_us_loss: -0.0914 - val_afs_loss: -0.1734 - val_bg_loss: -0.9887 - val_pz_dice_coefficient: 0.5277 - val_cz_dice_coefficient: 0.5185 - val_us_dice_coefficient: 0.0914 - val_afs_dice_coefficient: 0.1734 - val_bg_dice_coefficient: 0.9887
#
# Epoch 00058: val_loss did not improve from -2.30185
# Epoch 59/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.5704 - pz_loss: -0.5830 - cz_loss: -0.5930 - us_loss: -0.1003 - afs_loss: -0.3015 - bg_loss: -0.9926 - pz_dice_coefficient: 0.5830 - cz_dice_coefficient: 0.5930 - us_dice_coefficient: 0.1003 - afs_dice_coefficient: 0.3015 - bg_dice_coefficient: 0.9926 - val_loss: -2.2781 - val_pz_loss: -0.5234 - val_cz_loss: -0.5129 - val_us_loss: -0.0946 - val_afs_loss: -0.1594 - val_bg_loss: -0.9879 - val_pz_dice_coefficient: 0.5234 - val_cz_dice_coefficient: 0.5129 - val_us_dice_coefficient: 0.0946 - val_afs_dice_coefficient: 0.1594 - val_bg_dice_coefficient: 0.9879
#
# Epoch 00059: val_loss did not improve from -2.30185
# Epoch 60/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.5613 - pz_loss: -0.5761 - cz_loss: -0.5852 - us_loss: -0.1001 - afs_loss: -0.3076 - bg_loss: -0.9924 - pz_dice_coefficient: 0.5761 - cz_dice_coefficient: 0.5852 - us_dice_coefficient: 0.1001 - afs_dice_coefficient: 0.3076 - bg_dice_coefficient: 0.9924 - val_loss: -2.2836 - val_pz_loss: -0.5247 - val_cz_loss: -0.5179 - val_us_loss: -0.0942 - val_afs_loss: -0.1588 - val_bg_loss: -0.9880 - val_pz_dice_coefficient: 0.5247 - val_cz_dice_coefficient: 0.5179 - val_us_dice_coefficient: 0.0942 - val_afs_dice_coefficient: 0.1588 - val_bg_dice_coefficient: 0.9880
#
# Epoch 00060: val_loss did not improve from -2.30185
# Epoch 61/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.5389 - pz_loss: -0.5770 - cz_loss: -0.5696 - us_loss: -0.1002 - afs_loss: -0.2996 - bg_loss: -0.9925 - pz_dice_coefficient: 0.5770 - cz_dice_coefficient: 0.5696 - us_dice_coefficient: 0.1002 - afs_dice_coefficient: 0.2996 - bg_dice_coefficient: 0.9925 - val_loss: -2.2877 - val_pz_loss: -0.5338 - val_cz_loss: -0.5167 - val_us_loss: -0.0951 - val_afs_loss: -0.1543 - val_bg_loss: -0.9878 - val_pz_dice_coefficient: 0.5338 - val_cz_dice_coefficient: 0.5167 - val_us_dice_coefficient: 0.0951 - val_afs_dice_coefficient: 0.1543 - val_bg_dice_coefficient: 0.9878
#
# Epoch 00061: val_loss did not improve from -2.30185
# Epoch 62/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.5717 - pz_loss: -0.5797 - cz_loss: -0.5842 - us_loss: -0.0988 - afs_loss: -0.3165 - bg_loss: -0.9926 - pz_dice_coefficient: 0.5797 - cz_dice_coefficient: 0.5842 - us_dice_coefficient: 0.0988 - afs_dice_coefficient: 0.3165 - bg_dice_coefficient: 0.9926 - val_loss: -2.2764 - val_pz_loss: -0.5323 - val_cz_loss: -0.5155 - val_us_loss: -0.0933 - val_afs_loss: -0.1467 - val_bg_loss: -0.9887 - val_pz_dice_coefficient: 0.5323 - val_cz_dice_coefficient: 0.5155 - val_us_dice_coefficient: 0.0933 - val_afs_dice_coefficient: 0.1467 - val_bg_dice_coefficient: 0.9887
#
# Epoch 00062: val_loss did not improve from -2.30185
# Epoch 63/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.5475 - pz_loss: -0.5772 - cz_loss: -0.5676 - us_loss: -0.0982 - afs_loss: -0.3120 - bg_loss: -0.9925 - pz_dice_coefficient: 0.5772 - cz_dice_coefficient: 0.5676 - us_dice_coefficient: 0.0982 - afs_dice_coefficient: 0.3120 - bg_dice_coefficient: 0.9925 - val_loss: -2.2923 - val_pz_loss: -0.5346 - val_cz_loss: -0.5178 - val_us_loss: -0.0833 - val_afs_loss: -0.1682 - val_bg_loss: -0.9884 - val_pz_dice_coefficient: 0.5346 - val_cz_dice_coefficient: 0.5178 - val_us_dice_coefficient: 0.0833 - val_afs_dice_coefficient: 0.1682 - val_bg_dice_coefficient: 0.9884
#
# Epoch 00063: val_loss did not improve from -2.30185
# Epoch 64/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.5626 - pz_loss: -0.5828 - cz_loss: -0.5763 - us_loss: -0.1004 - afs_loss: -0.3104 - bg_loss: -0.9927 - pz_dice_coefficient: 0.5828 - cz_dice_coefficient: 0.5763 - us_dice_coefficient: 0.1004 - afs_dice_coefficient: 0.3104 - bg_dice_coefficient: 0.9927 - val_loss: -2.2695 - val_pz_loss: -0.5226 - val_cz_loss: -0.5087 - val_us_loss: -0.0935 - val_afs_loss: -0.1567 - val_bg_loss: -0.9880 - val_pz_dice_coefficient: 0.5226 - val_cz_dice_coefficient: 0.5087 - val_us_dice_coefficient: 0.0935 - val_afs_dice_coefficient: 0.1567 - val_bg_dice_coefficient: 0.9880
#
# Epoch 00064: val_loss did not improve from -2.30185
# Epoch 65/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.5529 - pz_loss: -0.5826 - cz_loss: -0.5821 - us_loss: -0.0962 - afs_loss: -0.2995 - bg_loss: -0.9925 - pz_dice_coefficient: 0.5826 - cz_dice_coefficient: 0.5821 - us_dice_coefficient: 0.0962 - afs_dice_coefficient: 0.2995 - bg_dice_coefficient: 0.9925 - val_loss: -2.2714 - val_pz_loss: -0.5249 - val_cz_loss: -0.5181 - val_us_loss: -0.0861 - val_afs_loss: -0.1543 - val_bg_loss: -0.9881 - val_pz_dice_coefficient: 0.5249 - val_cz_dice_coefficient: 0.5181 - val_us_dice_coefficient: 0.0861 - val_afs_dice_coefficient: 0.1543 - val_bg_dice_coefficient: 0.9881
#
# Epoch 00065: val_loss did not improve from -2.30185
# Epoch 66/400
# 58/58 [==============================] - 76s 1s/step - loss: -2.5472 - pz_loss: -0.5795 - cz_loss: -0.5755 - us_loss: -0.0966 - afs_loss: -0.3031 - bg_loss: -0.9925 - pz_dice_coefficient: 0.5795 - cz_dice_coefficient: 0.5755 - us_dice_coefficient: 0.0966 - afs_dice_coefficient: 0.3031 - bg_dice_coefficient: 0.9925 - val_loss: -2.2746 - val_pz_loss: -0.5223 - val_cz_loss: -0.5159 - val_us_loss: -0.0910 - val_afs_loss: -0.1570 - val_bg_loss: -0.9884 - val_pz_dice_coefficient: 0.5223 - val_cz_dice_coefficient: 0.5159 - val_us_dice_coefficient: 0.0910 - val_afs_dice_coefficient: 0.1570 - val_bg_dice_coefficient: 0.9884
#
# Epoch 00066: val_loss did not improve from -2.30185
# Epoch 67/400
# ...
#
# Epoch 00236: val_loss did not improve from -4.19902
# Epoch 237/400
# 58/58 [==============================] - 75s 1s/step - loss: -4.6314 - pz_loss: -0.8735 - cz_loss: -0.9307 - us_loss: -0.9577 - afs_loss: -0.8755 - bg_loss: -0.9941 - pz_dice_coefficient: 0.8735 - cz_dice_coefficient: 0.9307 - us_dice_coefficient: 0.9577 - afs_dice_coefficient: 0.8755 - bg_dice_coefficient: 0.9941 - val_loss: -4.1372 - val_pz_loss: -0.7659 - val_cz_loss: -0.8450 - val_us_loss: -0.9309 - val_afs_loss: -0.6061 - val_bg_loss: -0.9893 - val_pz_dice_coefficient: 0.7659 - val_cz_dice_coefficient: 0.8450 - val_us_dice_coefficient: 0.9309 - val_afs_dice_coefficient: 0.6061 - val_bg_dice_coefficient: 0.9893
#
# Epoch 00237: val_loss did not improve from -4.19902
# Epoch 238/400
# 58/58 [==============================] - 75s 1s/step - loss: -4.6594 - pz_loss: -0.8908 - cz_loss: -0.9370 - us_loss: -0.9588 - afs_loss: -0.8782 - bg_loss: -0.9946 - pz_dice_coefficient: 0.8908 - cz_dice_coefficient: 0.9370 - us_dice_coefficient: 0.9588 - afs_dice_coefficient: 0.8782 - bg_dice_coefficient: 0.9946 - val_loss: -4.1497 - val_pz_loss: -0.7755 - val_cz_loss: -0.8489 - val_us_loss: -0.9295 - val_afs_loss: -0.6063 - val_bg_loss: -0.9895 - val_pz_dice_coefficient: 0.7755 - val_cz_dice_coefficient: 0.8489 - val_us_dice_coefficient: 0.9295 - val_afs_dice_coefficient: 0.6063 - val_bg_dice_coefficient: 0.9895
#
# Epoch 00238: val_loss did not improve from -4.19902
# Epoch 239/400
# 58/58 [==============================] - 76s 1s/step - loss: -4.6666 - pz_loss: -0.8928 - cz_loss: -0.9339 - us_loss: -0.9617 - afs_loss: -0.8835 - bg_loss: -0.9947 - pz_dice_coefficient: 0.8928 - cz_dice_coefficient: 0.9339 - us_dice_coefficient: 0.9617 - afs_dice_coefficient: 0.8835 - bg_dice_coefficient: 0.9947 - val_loss: -4.1427 - val_pz_loss: -0.7774 - val_cz_loss: -0.8444 - val_us_loss: -0.9296 - val_afs_loss: -0.6017 - val_bg_loss: -0.9896 - val_pz_dice_coefficient: 0.7774 - val_cz_dice_coefficient: 0.8444 - val_us_dice_coefficient: 0.9296 - val_afs_dice_coefficient: 0.6017 - val_bg_dice_coefficient: 0.9896
#
# Epoch 00239: val_loss did not improve from -4.19902
# Epoch 240/400
# 58/58 [==============================] - 76s 1s/step - loss: -4.6706 - pz_loss: -0.8938 - cz_loss: -0.9365 - us_loss: -0.9587 - afs_loss: -0.8867 - bg_loss: -0.9948 - pz_dice_coefficient: 0.8938 - cz_dice_coefficient: 0.9365 - us_dice_coefficient: 0.9587 - afs_dice_coefficient: 0.8867 - bg_dice_coefficient: 0.9948 - val_loss: -4.1544 - val_pz_loss: -0.7776 - val_cz_loss: -0.8488 - val_us_loss: -0.9291 - val_afs_loss: -0.6095 - val_bg_loss: -0.9895 - val_pz_dice_coefficient: 0.7776 - val_cz_dice_coefficient: 0.8488 - val_us_dice_coefficient: 0.9291 - val_afs_dice_coefficient: 0.6095 - val_bg_dice_coefficient: 0.9895
#
# Epoch 00240: val_loss did not improve from -4.19902
# Epoch 241/400
# 58/58 [==============================] - 76s 1s/step - loss: -4.6688 - pz_loss: -0.8938 - cz_loss: -0.9387 - us_loss: -0.9586 - afs_loss: -0.8828 - bg_loss: -0.9949 - pz_dice_coefficient: 0.8938 - cz_dice_coefficient: 0.9387 - us_dice_coefficient: 0.9586 - afs_dice_coefficient: 0.8828 - bg_dice_coefficient: 0.9949 - val_loss: -4.1596 - val_pz_loss: -0.7773 - val_cz_loss: -0.8496 - val_us_loss: -0.9283 - val_afs_loss: -0.6149 - val_bg_loss: -0.9894 - val_pz_dice_coefficient: 0.7773 - val_cz_dice_coefficient: 0.8496 - val_us_dice_coefficient: 0.9283 - val_afs_dice_coefficient: 0.6149 - val_bg_dice_coefficient: 0.9894
#
# Epoch 00241: val_loss did not improve from -4.19902
# Epoch 242/400
# 58/58 [==============================] - 76s 1s/step - loss: -4.6688 - pz_loss: -0.8951 - cz_loss: -0.9381 - us_loss: -0.9589 - afs_loss: -0.8817 - bg_loss: -0.9950 - pz_dice_coefficient: 0.8951 - cz_dice_coefficient: 0.9381 - us_dice_coefficient: 0.9589 - afs_dice_coefficient: 0.8817 - bg_dice_coefficient: 0.9950 - val_loss: -4.1680 - val_pz_loss: -0.7817 - val_cz_loss: -0.8564 - val_us_loss: -0.9290 - val_afs_loss: -0.6114 - val_bg_loss: -0.9895 - val_pz_dice_coefficient: 0.7817 - val_cz_dice_coefficient: 0.8564 - val_us_dice_coefficient: 0.9290 - val_afs_dice_coefficient: 0.6114 - val_bg_dice_coefficient: 0.9895
#
# Epoch 00242: val_loss did not improve from -4.19902
# Epoch 243/400
# 58/58 [==============================] - 76s 1s/step - loss: -4.6610 - pz_loss: -0.8950 - cz_loss: -0.9364 - us_loss: -0.9588 - afs_loss: -0.8760 - bg_loss: -0.9948 - pz_dice_coefficient: 0.8950 - cz_dice_coefficient: 0.9364 - us_dice_coefficient: 0.9588 - afs_dice_coefficient: 0.8760 - bg_dice_coefficient: 0.9948 - val_loss: -4.1677 - val_pz_loss: -0.7853 - val_cz_loss: -0.8399 - val_us_loss: -0.9300 - val_afs_loss: -0.6230 - val_bg_loss: -0.9894 - val_pz_dice_coefficient: 0.7853 - val_cz_dice_coefficient: 0.8399 - val_us_dice_coefficient: 0.9300 - val_afs_dice_coefficient: 0.6230 - val_bg_dice_coefficient: 0.9894
#
# Epoch 00243: val_loss did not improve from -4.19902
# Epoch 244/400
# 58/58 [==============================] - 76s 1s/step - loss: -4.6705 - pz_loss: -0.8977 - cz_loss: -0.9358 - us_loss: -0.9598 - afs_loss: -0.8823 - bg_loss: -0.9949 - pz_dice_coefficient: 0.8977 - cz_dice_coefficient: 0.9358 - us_dice_coefficient: 0.9598 - afs_dice_coefficient: 0.8823 - bg_dice_coefficient: 0.9949 - val_loss: -4.1317 - val_pz_loss: -0.7652 - val_cz_loss: -0.8464 - val_us_loss: -0.9291 - val_afs_loss: -0.6016 - val_bg_loss: -0.9894 - val_pz_dice_coefficient: 0.7652 - val_cz_dice_coefficient: 0.8464 - val_us_dice_coefficient: 0.9291 - val_afs_dice_coefficient: 0.6016 - val_bg_dice_coefficient: 0.9894
#
# Epoch 00244: val_loss did not improve from -4.19902
# Epoch 245/400
# 58/58 [==============================] - 76s 1s/step - loss: -4.6808 - pz_loss: -0.8963 - cz_loss: -0.9400 - us_loss: -0.9609 - afs_loss: -0.8885 - bg_loss: -0.9950 - pz_dice_coefficient: 0.8963 - cz_dice_coefficient: 0.9400 - us_dice_coefficient: 0.9609 - afs_dice_coefficient: 0.8885 - bg_dice_coefficient: 0.9950 - val_loss: -4.1533 - val_pz_loss: -0.7755 - val_cz_loss: -0.8494 - val_us_loss: -0.9298 - val_afs_loss: -0.6090 - val_bg_loss: -0.9896 - val_pz_dice_coefficient: 0.7755 - val_cz_dice_coefficient: 0.8494 - val_us_dice_coefficient: 0.9298 - val_afs_dice_coefficient: 0.6090 - val_bg_dice_coefficient: 0.9896
#
# Epoch 00245: val_loss did not improve from -4.19902
# Epoch 246/400
# 58/58 [==============================] - 76s 1s/step - loss: -4.6807 - pz_loss: -0.9007 - cz_loss: -0.9403 - us_loss: -0.9604 - afs_loss: -0.8843 - bg_loss: -0.9950 - pz_dice_coefficient: 0.9007 - cz_dice_coefficient: 0.9403 - us_dice_coefficient: 0.9604 - afs_dice_coefficient: 0.8843 - bg_dice_coefficient: 0.9950 - val_loss: -4.1453 - val_pz_loss: -0.7801 - val_cz_loss: -0.8484 - val_us_loss: -0.9296 - val_afs_loss: -0.5977 - val_bg_loss: -0.9895 - val_pz_dice_coefficient: 0.7801 - val_cz_dice_coefficient: 0.8484 - val_us_dice_coefficient: 0.9296 - val_afs_dice_coefficient: 0.5977 - val_bg_dice_coefficient: 0.9895
#
# Epoch 00246: val_loss did not improve from -4.19902
# Epoch 247/400
# 58/58 [==============================] - 76s 1s/step - loss: -4.6769 - pz_loss: -0.8923 - cz_loss: -0.9389 - us_loss: -0.9594 - afs_loss: -0.8915 - bg_loss: -0.9948 - pz_dice_coefficient: 0.8923 - cz_dice_coefficient: 0.9389 - us_dice_coefficient: 0.9594 - afs_dice_coefficient: 0.8915 - bg_dice_coefficient: 0.9948 - val_loss: -4.1459 - val_pz_loss: -0.7773 - val_cz_loss: -0.8469 - val_us_loss: -0.9293 - val_afs_loss: -0.6028 - val_bg_loss: -0.9897 - val_pz_dice_coefficient: 0.7773 - val_cz_dice_coefficient: 0.8469 - val_us_dice_coefficient: 0.9293 - val_afs_dice_coefficient: 0.6028 - val_bg_dice_coefficient: 0.9897
#
# Epoch 00247: val_loss did not improve from -4.19902
# Epoch 248/400
# 58/58 [==============================] - 76s 1s/step - loss: -4.6728 - pz_loss: -0.8995 - cz_loss: -0.9406 - us_loss: -0.9561 - afs_loss: -0.8816 - bg_loss: -0.9950 - pz_dice_coefficient: 0.8995 - cz_dice_coefficient: 0.9406 - us_dice_coefficient: 0.9561 - afs_dice_coefficient: 0.8816 - bg_dice_coefficient: 0.9950 - val_loss: -4.1636 - val_pz_loss: -0.7835 - val_cz_loss: -0.8508 - val_us_loss: -0.9309 - val_afs_loss: -0.6088 - val_bg_loss: -0.9897 - val_pz_dice_coefficient: 0.7835 - val_cz_dice_coefficient: 0.8508 - val_us_dice_coefficient: 0.9309 - val_afs_dice_coefficient: 0.6088 - val_bg_dice_coefficient: 0.9897
#
# Epoch 00248: val_loss did not improve from -4.19902
# Epoch 249/400
# 58/58 [==============================] - 76s 1s/step - loss: -4.6652 - pz_loss: -0.8895 - cz_loss: -0.9340 - us_loss: -0.9598 - afs_loss: -0.8872 - bg_loss: -0.9946 - pz_dice_coefficient: 0.8895 - cz_dice_coefficient: 0.9340 - us_dice_coefficient: 0.9598 - afs_dice_coefficient: 0.8872 - bg_dice_coefficient: 0.9946 - val_loss: -4.1285 - val_pz_loss: -0.7707 - val_cz_loss: -0.8416 - val_us_loss: -0.9313 - val_afs_loss: -0.5960 - val_bg_loss: -0.9888 - val_pz_dice_coefficient: 0.7707 - val_cz_dice_coefficient: 0.8416 - val_us_dice_coefficient: 0.9313 - val_afs_dice_coefficient: 0.5960 - val_bg_dice_coefficient: 0.9888
#
# Epoch 00249: val_loss did not improve from -4.19902
# Epoch 250/400
# 58/58 [==============================] - 76s 1s/step - loss: -4.6539 - pz_loss: -0.8847 - cz_loss: -0.9377 - us_loss: -0.9544 - afs_loss: -0.8826 - bg_loss: -0.9946 - pz_dice_coefficient: 0.8847 - cz_dice_coefficient: 0.9377 - us_dice_coefficient: 0.9544 - afs_dice_coefficient: 0.8826 - bg_dice_coefficient: 0.9946 - val_loss: -4.1336 - val_pz_loss: -0.7807 - val_cz_loss: -0.8411 - val_us_loss: -0.9278 - val_afs_loss: -0.5946 - val_bg_loss: -0.9895 - val_pz_dice_coefficient: 0.7807 - val_cz_dice_coefficient: 0.8411 - val_us_dice_coefficient: 0.9278 - val_afs_dice_coefficient: 0.5946 - val_bg_dice_coefficient: 0.9895
#
# Epoch 00250: val_loss did not improve from -4.19902
# Epoch 251/400
# 58/58 [==============================] - 76s 1s/step - loss: -4.6652 - pz_loss: -0.8910 - cz_loss: -0.9336 - us_loss: -0.9603 - afs_loss: -0.8853 - bg_loss: -0.9949 - pz_dice_coefficient: 0.8910 - cz_dice_coefficient: 0.9336 - us_dice_coefficient: 0.9603 - afs_dice_coefficient: 0.8853 - bg_dice_coefficient: 0.9949 - val_loss: -4.1363 - val_pz_loss: -0.7721 - val_cz_loss: -0.8492 - val_us_loss: -0.9295 - val_afs_loss: -0.5961 - val_bg_loss: -0.9895 - val_pz_dice_coefficient: 0.7721 - val_cz_dice_coefficient: 0.8492 - val_us_dice_coefficient: 0.9295 - val_afs_dice_coefficient: 0.5961 - val_bg_dice_coefficient: 0.9895
#
# Epoch 00251: val_loss did not improve from -4.19902
# Epoch 252/400
# 58/58 [==============================] - 76s 1s/step - loss: -4.6742 - pz_loss: -0.8932 - cz_loss: -0.9386 - us_loss: -0.9610 - afs_loss: -0.8865 - bg_loss: -0.9949 - pz_dice_coefficient: 0.8932 - cz_dice_coefficient: 0.9386 - us_dice_coefficient: 0.9610 - afs_dice_coefficient: 0.8865 - bg_dice_coefficient: 0.9949 - val_loss: -4.1521 - val_pz_loss: -0.7835 - val_cz_loss: -0.8515 - val_us_loss: -0.9296 - val_afs_loss: -0.5978 - val_bg_loss: -0.9896 - val_pz_dice_coefficient: 0.7835 - val_cz_dice_coefficient: 0.8515 - val_us_dice_coefficient: 0.9296 - val_afs_dice_coefficient: 0.5978 - val_bg_dice_coefficient: 0.9896
#
# Epoch 00252: val_loss did not improve from -4.19902
# Epoch 253/400
# 58/58 [==============================] - 76s 1s/step - loss: -4.6759 - pz_loss: -0.8940 - cz_loss: -0.9357 - us_loss: -0.9613 - afs_loss: -0.8899 - bg_loss: -0.9950 - pz_dice_coefficient: 0.8940 - cz_dice_coefficient: 0.9357 - us_dice_coefficient: 0.9613 - afs_dice_coefficient: 0.8899 - bg_dice_coefficient: 0.9950 - val_loss: -4.1347 - val_pz_loss: -0.7700 - val_cz_loss: -0.8467 - val_us_loss: -0.9324 - val_afs_loss: -0.5962 - val_bg_loss: -0.9894 - val_pz_dice_coefficient: 0.7700 - val_cz_dice_coefficient: 0.8467 - val_us_dice_coefficient: 0.9324 - val_afs_dice_coefficient: 0.5962 - val_bg_dice_coefficient: 0.9894
#
# Epoch 00253: val_loss did not improve from -4.19902
# Epoch 254/400
# 58/58 [==============================] - 76s 1s/step - loss: -4.6837 - pz_loss: -0.8978 - cz_loss: -0.9407 - us_loss: -0.9612 - afs_loss: -0.8889 - bg_loss: -0.9951 - pz_dice_coefficient: 0.8978 - cz_dice_coefficient: 0.9407 - us_dice_coefficient: 0.9612 - afs_dice_coefficient: 0.8889 - bg_dice_coefficient: 0.9951 - val_loss: -4.1605 - val_pz_loss: -0.7787 - val_cz_loss: -0.8503 - val_us_loss: -0.9297 - val_afs_loss: -0.6122 - val_bg_loss: -0.9896 - val_pz_dice_coefficient: 0.7787 - val_cz_dice_coefficient: 0.8503 - val_us_dice_coefficient: 0.9297 - val_afs_dice_coefficient: 0.6122 - val_bg_dice_coefficient: 0.9896
#
# Epoch 00254: val_loss did not improve from -4.19902
# Epoch 255/400
# 58/58 [==============================] - 76s 1s/step - loss: -4.6869 - pz_loss: -0.9015 - cz_loss: -0.9376 - us_loss: -0.9602 - afs_loss: -0.8927 - bg_loss: -0.9950 - pz_dice_coefficient: 0.9015 - cz_dice_coefficient: 0.9376 - us_dice_coefficient: 0.9602 - afs_dice_coefficient: 0.8927 - bg_dice_coefficient: 0.9950 - val_loss: -4.1476 - val_pz_loss: -0.7729 - val_cz_loss: -0.8496 - val_us_loss: -0.9302 - val_afs_loss: -0.6054 - val_bg_loss: -0.9896 - val_pz_dice_coefficient: 0.7729 - val_cz_dice_coefficient: 0.8496 - val_us_dice_coefficient: 0.9302 - val_afs_dice_coefficient: 0.6054 - val_bg_dice_coefficient: 0.9896
#
# Epoch 00255: val_loss did not improve from -4.19902
# Epoch 256/400
# 58/58 [==============================] - 76s 1s/step - loss: -4.6877 - pz_loss: -0.9004 - cz_loss: -0.9413 - us_loss: -0.9607 - afs_loss: -0.8902 - bg_loss: -0.9951 - pz_dice_coefficient: 0.9004 - cz_dice_coefficient: 0.9413 - us_dice_coefficient: 0.9607 - afs_dice_coefficient: 0.8902 - bg_dice_coefficient: 0.9951 - val_loss: -4.1528 - val_pz_loss: -0.7724 - val_cz_loss: -0.8499 - val_us_loss: -0.9307 - val_afs_loss: -0.6103 - val_bg_loss: -0.9895 - val_pz_dice_coefficient: 0.7724 - val_cz_dice_coefficient: 0.8499 - val_us_dice_coefficient: 0.9307 - val_afs_dice_coefficient: 0.6103 - val_bg_dice_coefficient: 0.9895
#
# Epoch 00256: val_loss did not improve from -4.19902
# Epoch 257/400
# 58/58 [==============================] - 76s 1s/step - loss: -4.6834 - pz_loss: -0.9003 - cz_loss: -0.9382 - us_loss: -0.9601 - afs_loss: -0.8897 - bg_loss: -0.9951 - pz_dice_coefficient: 0.9003 - cz_dice_coefficient: 0.9382 - us_dice_coefficient: 0.9601 - afs_dice_coefficient: 0.8897 - bg_dice_coefficient: 0.9951 - val_loss: -4.1597 - val_pz_loss: -0.7795 - val_cz_loss: -0.8527 - val_us_loss: -0.9279 - val_afs_loss: -0.6099 - val_bg_loss: -0.9897 - val_pz_dice_coefficient: 0.7795 - val_cz_dice_coefficient: 0.8527 - val_us_dice_coefficient: 0.9279 - val_afs_dice_coefficient: 0.6099 - val_bg_dice_coefficient: 0.9897
#
# Epoch 00257: val_loss did not improve from -4.19902
# Epoch 258/400
# 58/58 [==============================] - 76s 1s/step - loss: -4.6896 - pz_loss: -0.9007 - cz_loss: -0.9418 - us_loss: -0.9610 - afs_loss: -0.8910 - bg_loss: -0.9951 - pz_dice_coefficient: 0.9007 - cz_dice_coefficient: 0.9418 - us_dice_coefficient: 0.9610 - afs_dice_coefficient: 0.8910 - bg_dice_coefficient: 0.9951 - val_loss: -4.1395 - val_pz_loss: -0.7730 - val_cz_loss: -0.8525 - val_us_loss: -0.9300 - val_afs_loss: -0.5944 - val_bg_loss: -0.9896 - val_pz_dice_coefficient: 0.7730 - val_cz_dice_coefficient: 0.8525 - val_us_dice_coefficient: 0.9300 - val_afs_dice_coefficient: 0.5944 - val_bg_dice_coefficient: 0.9896
#
# Epoch 00258: val_loss did not improve from -4.19902
# Epoch 259/400
# 58/58 [==============================] - 76s 1s/step - loss: -4.6782 - pz_loss: -0.8967 - cz_loss: -0.9404 - us_loss: -0.9596 - afs_loss: -0.8864 - bg_loss: -0.9951 - pz_dice_coefficient: 0.8967 - cz_dice_coefficient: 0.9404 - us_dice_coefficient: 0.9596 - afs_dice_coefficient: 0.8864 - bg_dice_coefficient: 0.9951 - val_loss: -4.1178 - val_pz_loss: -0.7663 - val_cz_loss: -0.8475 - val_us_loss: -0.9306 - val_afs_loss: -0.5839 - val_bg_loss: -0.9894 - val_pz_dice_coefficient: 0.7663 - val_cz_dice_coefficient: 0.8475 - val_us_dice_coefficient: 0.9306 - val_afs_dice_coefficient: 0.5839 - val_bg_dice_coefficient: 0.9894
#
# Epoch 00259: val_loss did not improve from -4.19902
# Epoch 00259: early stopping

# %%
def predict(val_imgs, val_gt_list, modelName):
    # modelName: e.g. 'model_LR_5e-5_BN_DO_0.5_fold1.h5'
    nrChanels = 1
    out_dir = 'predictions/'

    network = anisotopic_UNET()
    model = network.get_net(bn=True, do=False)
    model.load_weights(modelName)
    print(model.evaluate([val_imgs], val_gt_list , batch_size=1, verbose=1))
    out = model.predict([val_imgs], batch_size=2, verbose=1)
    

    np.save('predicted_' + modelName[:-3] + '.npy', out)

# %%
    epochs = 5  # sys.argv[1]
    LR = 5e-5  # sys.argv[2]
    foldNr = 1  # sys.argv[4]

    # val_imgs = np.load('/home/suhita/zonals/data/test_anneke/final_test_array_imgs.npy')
    val_imgs = np.load('drive/My Drive/prostrate/final_test_array_imgs.npy')
    print(val_imgs.shape)
    # val_gt = np.load('/home/suhita/zonals/data/test/image_npy_gt.npy')
    val_gt = np.load('drive/My Drive/prostrate/final_test_array_GT.npy')

    print(val_gt.shape)
    val_gt = val_gt.astype(np.uint8)
    val_gt_list = [val_gt[:, :, :, :, 0], val_gt[:, :, :, :, 1], val_gt[:, :, :, :, 2], val_gt[:, :, :, :, 3],
                   val_gt[:, :, :, :, 4]]
    predict(val_imgs, val_gt_list, 'UNet_zones_Fold1_LR_0.0005_final.h5')
# Out:
# (20, 32, 168, 168, 1)
# (20, 32, 168, 168, 5)
# 20/20 [==============================] - 9s 443ms/step
# 20/20 [==============================] - 15s 754ms/step
# [-4.125465369224548, -0.7731551110744477, -0.8570601373910904, -0.9271850526332855, -0.579103235900402, -0.9889618843793869, 0.7731551110744477, 0.8570601373910904, 0.9271850526332855, 0.579103235900402, 0.9889618843793869]

# %%
# !pip install SimpleITK

import numpy as np
import sys
import SimpleITK as sitk
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import os
import csv
import math
import matplotlib.cm as cm
import utils


def getDice(prediction, groundTruth):
    filter = sitk.LabelOverlapMeasuresImageFilter()
    filter.Execute(prediction, groundTruth)
    dice = filter.GetDiceCoefficient()
    return dice


def relativeAbsoluteVolumeDifference(prediction, groundTruth):
    # get number of pixels in segmentation
    connectedFilter = sitk.ConnectedComponentImageFilter()
    connectedComponents = connectedFilter.Execute(prediction)
    labelFilter = sitk.LabelShapeStatisticsImageFilter()
    labelFilter.Execute(connectedComponents)
    x = labelFilter.GetNumberOfLabels()
    if x == 0:
        return 0.0
    pixelsPrediction = labelFilter.GetNumberOfPixels(1)

    connectedComponents = connectedFilter.Execute(groundTruth)
    labelFilter = sitk.LabelShapeStatisticsImageFilter()
    labelFilter.Execute(connectedComponents)
    pixelsGT = labelFilter.GetNumberOfPixels(1)

    # compute and return relative absolute Volume Difference
    return (abs((pixelsPrediction / pixelsGT) - 1)) * 100


def getBoundaryDistances(prediction, groundTruth):
    # get surfaces
    contourP = sitk.BinaryContour(prediction, fullyConnected=True)
    maxFilter = sitk.MinimumMaximumImageFilter()
    maxFilter.Execute(contourP)
    x = maxFilter.GetMaximum()
    if maxFilter.GetMaximum() == 0:
        return (0.0, 0.0)
    contourGT = sitk.BinaryContour(groundTruth, fullyConnected=True)

    contourP_dist = sitk.DanielssonDistanceMap(contourP, inputIsBinary=True, squaredDistance=False,
                                               useImageSpacing=True)
    contourGT_dist = sitk.DanielssonDistanceMap(contourGT, inputIsBinary=True, squaredDistance=False,
                                                useImageSpacing=True)

    # image with directed distance from prediction contour to GT contour
    contourP_masked = sitk.Mask(contourP_dist, contourGT)

    # image with directed distance from GT contour to predicted contour
    contourGT_masked = sitk.Mask(contourGT_dist, contourP)
    # sitk.WriteImage(contourGT_masked, 'contourGT_masked.nrrd')
    sitk.WriteImage(contourP_masked, 'contourP_masked.nrrd')

    contourP_arr = sitk.GetArrayFromImage(contourP)
    contourP_arr = contourP_arr.astype(np.bool)
    contourP_arr_inv = np.invert(contourP_arr)
    contourGT_arr = sitk.GetArrayFromImage(contourGT)
    contourGT_arr = contourGT_arr.astype(np.bool)
    contourGT_arr_inv = np.invert(contourGT_arr)

    dist_PredtoGT = sitk.GetArrayFromImage(contourP_masked)
    dist_PredtoGT = np.ma.masked_array(dist_PredtoGT, contourGT_arr_inv).compressed()

    dist_GTtoPred = sitk.GetArrayFromImage(contourGT_masked)
    dist_GTtoPred = np.ma.masked_array(dist_GTtoPred, contourP_arr_inv).compressed()

    hausdorff = max(np.percentile(dist_PredtoGT, 95), np.percentile(dist_GTtoPred, 95))
    distances = np.concatenate((dist_PredtoGT, dist_GTtoPred))
    mean = distances.mean()
    return (hausdorff, mean)


def evaluateFiles_zones(GT_array, pred_directory, csvName):
    with open(csvName + '.csv', 'w') as csvfile:
        csvwriter = csv.writer(csvfile, delimiter=';', lineterminator='\n',
                               quotechar='|', quoting=csv.QUOTE_MINIMAL)
        csvwriter.writerow(
            ['Case', 'PZ Dice', 'CZ Dice', 'US Dice', 'AFS Dice', 'PZ MeanDis', 'CZ MeanDis', 'US MeanDis',
             'AFS MeanDis'])

        nrImgs = GT_array.shape[0]
        dices = np.zeros((nrImgs, 4), dtype=np.float32)
        print(dices.shape)
        mad = np.zeros((nrImgs, 4), dtype=np.float32)

        for imgNumber in range(0, nrImgs):
            print('Case' + str(imgNumber))
            values = ['Case' + str(imgNumber)]
            temp_dice = []
            temp_mad = []

            for zoneIndex in range(0, 4):
                pred_arr = np.load(pred_directory + 'predicted_' + str(imgNumber) + '.npy')[zoneIndex]
                pred_arr = thresholdArray(pred_arr, 0.3)
                # pred_arr = pred_arr.astype(int)
                maxValue = np.max(pred_arr)
                pred_img = sitk.GetImageFromArray(pred_arr)

                GT_label = sitk.GetImageFromArray(GT_array[imgNumber, :, :, :, zoneIndex])
                #####pred_img = utils.resampleToReference(pred_img, GT_label, sitk.sitkNearestNeighbor, 0)
                pred_img = utils.castImage(pred_img, sitk.sitkUInt8)
                ####GT_label = utils.resampleToReference(GT_label, pred_img, sitk.sitkNearestNeighbor, 0)
                GT_label = utils.castImage(GT_label, sitk.sitkUInt8)

                sitk.WriteImage(pred_img, 'predImg.nrrd')
                sitk.WriteImage(GT_label, 'GT_label.nrrd')

                dice = getDice(pred_img, GT_label)
                temp_dice.append(dice)
                print(dice)
                # avd = relativeAbsoluteVolumeDifference(pred_img, GT_label)
                [hausdorff, avgDist] = getBoundaryDistances(pred_img, GT_label)
                temp_mad.append(avgDist)
                # values.append(dice)
                # values.append(avgDist)
                dices[imgNumber, zoneIndex] = dice
                mad[imgNumber, zoneIndex] = avgDist

            values.append(temp_dice[0])
            values.append(temp_dice[1])
            values.append(temp_dice[2])
            values.append(temp_dice[3])

            values.append(temp_mad[0])
            values.append(temp_mad[1])
            values.append(temp_mad[2])
            values.append(temp_mad[3])
            # values.append(temp_mad)
            csvwriter.writerow(values)

        csvwriter.writerow('')
        average = ['Average', np.average(dices[:, 0]), np.average(dices[:, 1]), np.average(dices[:, 2]),
                   np.average(dices[:, 3]), np.average(mad[:, 0]), np.average(mad[:, 1]), np.average(mad[:, 2]),
                   np.average(mad[:, 3])]
        median = ['Median', np.median(dices[:, 0]), np.median(dices[:, 1]), np.median(dices[:, 2]),
                  np.median(dices[:, 3]), np.median(mad[:, 0]), np.median(mad[:, 1]), np.median(mad[:, 2]),
                  np.median(mad[:, 3])]
        std = ['STD', np.std(dices[:, 0]), np.std(dices[:, 1]), np.std(dices[:, 2]),
               np.std(dices[:, 3]), np.std(mad[:, 0]), np.std(mad[:, 1]), np.std(mad[:, 2]),
               np.std(mad[:, 3])]

        csvwriter.writerow(average)
        csvwriter.writerow(median)
        csvwriter.writerow(std)

        print('Dices')
        print(np.average(dices[:, 0]))
        print(np.average(dices[:, 1]))
        print(np.average(dices[:, 2]))
        print(np.average(dices[:, 3]))

        print('Mean Dist')
        print(np.average(mad[:, 0]))
        print(np.average(mad[:, 1]))
        print(np.average(mad[:, 2]))
        print(np.average(mad[:, 3]))


def evaluateFiles(GT_directory, pred_directory, csvName):
    with open(csvName + '.csv', 'w') as csvfile:
        csvwriter = csv.writer(csvfile, delimiter=';', lineterminator='\n',
                               quotechar='|', quoting=csv.QUOTE_MINIMAL)
        csvwriter.writerow(['Case', 'Dice', 'Average Volume Difference', '95-Hausdorff', 'Avg Hausdorff'])

        cases = os.listdir(GT_directory)

        for case in cases:
            pred_img = sitk.ReadImage(pred_directory + case + '/predicted_CC.nrrd')
            print(case[:-1])
            GT_label = sitk.ReadImage(GT_directory + case + '/Segmentation-label_whole.nrrd')
            GT_label = utils.castImage(GT_label, sitk.sitkUInt8)
            pred_img = utils.resampleToReference(pred_img, GT_label, sitk.sitkNearestNeighbor, 0)
            pred_img = utils.castImage(pred_img, sitk.sitkUInt8)
            dice = getDice(pred_img, GT_label)
            print(dice)
            avd = relativeAbsoluteVolumeDifference(pred_img, GT_label)
            [hausdorff, avgDist] = getBoundaryDistances(pred_img, GT_label)

            csvwriter.writerow([case, dice, avd, hausdorff, avgDist])


def visualizeResults(directory, img_tra, img_cor, img_sag, pred_img, GT_img, i):
    if not os.path.exists(directory + 'visualResults'):
        os.makedirs(directory + 'visualResults')

    contour = sitk.BinaryContour(pred_img, True)
    colors = [(1, 0, 0), (0, 0, 0)]  # R -> G -> B
    n_bins = 5  # Discretizes the interpolation into bins
    cmap_name = 'my_list'

    contourGT = sitk.BinaryContour(GT_img, True)
    colorsGT = [(1, 1, 0), (0, 0, 0)]  # R -> G -> B
    cmap_nameGT = 'GT'

    contourArray = sitk.GetArrayFromImage(contour)
    contourArray = np.flip(contourArray, axis=0)
    contourArrayGT = sitk.GetArrayFromImage(contourGT)
    contourArrayGT = np.flip(contourArrayGT, axis=0)
    imgArray_tra = sitk.GetArrayFromImage(img_tra)
    imgArray_tra = np.flip(imgArray_tra, axis=0)
    imgArray_cor = sitk.GetArrayFromImage(img_cor)
    imgArray_cor = np.flip(imgArray_cor, axis=0)
    imgArray_sag = sitk.GetArrayFromImage(img_sag)
    imgArray_sag = np.flip(imgArray_sag, axis=0)

    masked_data = np.ma.masked_where(contourArray == 0, contourArray)
    masked_dataGT = np.ma.masked_where(contourArrayGT == 0, contourArrayGT)
    z = imgArray_tra.shape[0]

    plt.subplots(3, 3, figsize=(30, 30))

    colormap = LinearSegmentedColormap.from_list(cmap_name, colors, N=n_bins)
    colormapGT = LinearSegmentedColormap.from_list(cmap_nameGT, colorsGT, N=n_bins)
    plt.subplot(3, 3, 1)
    plt.imshow(imgArray_tra[int(z / 3), :, :], 'gray')
    plt.imshow(masked_data[int(z / 3), :, :], cmap=colormap, interpolation='none')
    plt.imshow(masked_dataGT[int(z / 3), :, :], cmap=colormapGT, interpolation='none')
    plt.axis('off')

    plt.subplot(3, 3, 2)
    plt.imshow(imgArray_tra[int(z / 2), :, :], 'gray')
    plt.imshow(masked_data[int(z / 2), :, :], cmap=colormap, interpolation='none')
    plt.imshow(masked_dataGT[int(z / 2), :, :], cmap=colormapGT, interpolation='none')
    plt.axis('off')

    plt.subplot(3, 3, 3)
    plt.imshow(imgArray_tra[int(2 * (z / 3)), :, :], 'gray')
    plt.imshow(masked_data[int(2 * (z / 3)), :, :], cmap=colormap, interpolation='none')
    plt.imshow(masked_dataGT[int(2 * (z / 3)), :, :], cmap=colormapGT, interpolation='none')
    plt.axis('off')

    plt.subplot(3, 3, 4)
    plt.imshow(imgArray_cor[:, int(z / 3), :], 'gray')
    plt.imshow(masked_data[:, int(z / 3), :], cmap=colormap, interpolation='none')
    plt.imshow(masked_dataGT[:, int(z / 3), :], cmap=colormapGT, interpolation='none')
    plt.axis('off')

    plt.subplot(3, 3, 5)
    plt.imshow(imgArray_cor[:, int(z / 2), :], 'gray')
    plt.imshow(masked_data[:, int(z / 2), :], cmap=colormap, interpolation='none')
    plt.imshow(masked_dataGT[:, int(z / 2), :], cmap=colormapGT, interpolation='none')
    plt.axis('off')

    plt.subplot(3, 3, 6)
    plt.imshow(imgArray_cor[:, int(2 * (z / 3)), :], 'gray')
    plt.imshow(masked_data[:, int(2 * (z / 3)), :], cmap=colormap, interpolation='none')
    plt.imshow(masked_dataGT[:, int(2 * (z / 3)), :], cmap=colormapGT, interpolation='none')
    plt.axis('off')

    plt.subplot(3, 3, 7)
    plt.imshow(imgArray_sag[:, :, int(z / 3)], 'gray')
    plt.imshow(masked_data[:, :, int(z / 3)], cmap=colormap, interpolation='none')
    plt.imshow(masked_dataGT[:, :, int(z / 3)], cmap=colormapGT, interpolation='none')
    plt.axis('off')

    plt.subplot(3, 3, 8)
    plt.imshow(imgArray_sag[:, :, int(z / 2)], 'gray')
    plt.imshow(masked_data[:, :, int(z / 2)], cmap=colormap, interpolation='none')
    plt.imshow(masked_dataGT[:, :, int(z / 2)], cmap=colormapGT, interpolation='none')
    plt.axis('off')

    plt.subplot(3, 3, 9)
    plt.imshow(imgArray_sag[:, :, int(2 * (z / 3))], 'gray')
    plt.imshow(masked_data[:, :, int(2 * (z / 3))], cmap=colormap, interpolation='none')
    plt.imshow(masked_dataGT[:, :, int(z / 3)], cmap=colormapGT, interpolation='none')
    plt.axis('off')

    plt.savefig(directory + 'visualResults/img_' + str(i) + '.png')


def visualizeResultsSmall(directory, img_tra, img_cor, img_sag, pred_img, GT_img, i):
    if not os.path.exists(directory + 'visualResults'):
        os.makedirs(directory + 'visualResults')

    contour = sitk.BinaryContour(pred_img, True)
    colors = [(1, 0, 0), (0, 0, 0)]  # R -> G -> B
    n_bins = 5  # Discretizes the interpolation into bins
    cmap_name = 'my_list'

    contourGT = sitk.BinaryContour(GT_img, True)
    colorsGT = [(1, 1, 0), (0, 0, 0)]  # R -> G -> B
    cmap_nameGT = 'GT'

    contourArray = sitk.GetArrayFromImage(contour)
    contourArray = np.flip(contourArray, axis=0)
    contourArrayGT = sitk.GetArrayFromImage(contourGT)
    contourArrayGT = np.flip(contourArrayGT, axis=0)
    imgArray_tra = sitk.GetArrayFromImage(img_tra)
    imgArray_tra = np.flip(imgArray_tra, axis=0)
    imgArray_cor = sitk.GetArrayFromImage(img_cor)
    imgArray_cor = np.flip(imgArray_cor, axis=0)
    imgArray_sag = sitk.GetArrayFromImage(img_sag)
    imgArray_sag = np.flip(imgArray_sag, axis=0)

    masked_data = np.ma.masked_where(contourArray == 0, contourArray)
    masked_dataGT = np.ma.masked_where(contourArrayGT == 0, contourArrayGT)
    z = imgArray_tra.shape[0]

    plt.subplots(3, 3, figsize=(30, 30))

    colormap = LinearSegmentedColormap.from_list(cmap_name, colors, N=n_bins)
    colormapGT = LinearSegmentedColormap.from_list(cmap_nameGT, colorsGT, N=n_bins)

    plt.subplot(1, 3, 1)
    plt.imshow(imgArray_tra[int(z / 2), :, :], 'gray')
    plt.imshow(masked_data[int(z / 2), :, :], cmap=colormap, interpolation='none')
    plt.imshow(masked_dataGT[int(z / 2), :, :], cmap=colormapGT, interpolation='none')
    plt.axis('off')

    plt.subplot(1, 3, 2)
    plt.imshow(imgArray_sag[:, :, int(z / 2)], 'gray')
    plt.imshow(masked_data[:, :, int(z / 2)], cmap=colormap, interpolation='none')
    plt.imshow(masked_dataGT[:, :, int(z / 2)], cmap=colormapGT, interpolation='none')
    plt.axis('off')

    plt.subplot(1, 3, 3)
    plt.imshow(imgArray_cor[:, int(2 * (z / 3)), :], 'gray')
    plt.imshow(masked_data[:, int(2 * (z / 3)), :], cmap=colormap, interpolation='none')
    plt.imshow(masked_dataGT[:, int(2 * (z / 3)), :], cmap=colormapGT, interpolation='none')
    plt.axis('off')

    plt.savefig(directory + 'visualResults/img_' + str(i) + '.png')


def regionBasedEvaluation(directory, csvName):
    with open(csvName + '.csv', 'w') as csvfile:
        csvwriter = csv.writer(csvfile, delimiter=';', lineterminator='\n',
                               quotechar='|', quoting=csv.QUOTE_MINIMAL)
        csvwriter.writerow(
            ['Case', 'Dice Apex', 'Dice Mid', 'Dice Base', 'AVD Apex', 'AVD Mid', 'AVD Base', '95-Hausdorff Apex',
             '95-Hausdorff Mid', '95-Hausdorff Base', 'Avg Dis Apex', 'Avg Dis Mid', 'Avg Dis Base'])

        for i in range(0, 15):
            predicted_array = np.load(directory + '/predicted_test_' + str(i) + '.npy')
            GT_array = np.load(directory + 'imgs_test_GT_' + str(i) + '.npy')
            GT_array = GT_array.astype(np.uint8)
            pred_img = sitk.GetImageFromArray(predicted_array[0, :, :, :, 0])

            pred_img = utils.binaryThresholdImage(pred_img, 0.5)
            GT_label = sitk.GetImageFromArray(GT_array[:, :, :, 0])
            pred_img = utils.getLargestConnectedComponents(pred_img)
            pred_img.SetSpacing([0.5, 0.5, 0.5])
            GT_label.SetSpacing([0.5, 0.5, 0.5])

            # get boundingboxes
            bb_P = utils.getBoundingBox(pred_img)
            bb_GT = utils.getBoundingBox(GT_label)
            startZ = max(0, min(bb_P[2], bb_GT[2]) - 1)

            sizeZ = max(bb_P[2] + bb_P[5], bb_GT[2] + bb_P[5]) - startZ + 1

            apex_P = sitk.RegionOfInterest(pred_img, [168, 168, math.floor(sizeZ / 3)],
                                           [0, 0, startZ])
            apex_GT = sitk.RegionOfInterest(GT_label, [168, 168, math.floor(sizeZ / 3)],
                                            [0, 0, startZ])
            mid_P = sitk.RegionOfInterest(pred_img, [168, 168, math.floor(sizeZ / 3)],
                                          [0, 0, startZ + math.floor(sizeZ / 3)])
            mid_GT = sitk.RegionOfInterest(GT_label, [168, 168, math.floor(sizeZ / 3)],
                                           [0, 0, startZ + math.floor(sizeZ / 3)])
            base_P = sitk.RegionOfInterest(pred_img, [168, 168, math.floor(sizeZ / 3)],
                                           [0, 0, startZ + 2 * math.floor(sizeZ / 3)])
            base_GT = sitk.RegionOfInterest(GT_label, [168, 168, math.floor(sizeZ / 3)],
                                            [0, 0, startZ + 2 * math.floor(sizeZ / 3)])

            sitk.WriteImage(apex_P, 'apex_P.nrrd')
            sitk.WriteImage(apex_GT, 'apex_GT.nrrd')
            sitk.WriteImage(mid_P, 'mid_P.nrrd')
            sitk.WriteImage(mid_GT, 'mid_GT.nrrd')
            sitk.WriteImage(base_P, 'base_P.nrrd')
            sitk.WriteImage(base_GT, 'base_GT.nrrd')

            dice_apex = getDice(apex_P, apex_GT)
            avd_apex = relativeAbsoluteVolumeDifference(apex_P, apex_GT)
            [hausdorff_apex, avgDist_apex] = getBoundaryDistances(apex_P, apex_GT)

            dice_mid = getDice(mid_P, mid_GT)
            avd_mid = relativeAbsoluteVolumeDifference(mid_P, mid_GT)
            [hausdorff_mid, avgDist_mid] = getBoundaryDistances(mid_P, mid_GT)

            dice_base = getDice(base_P, base_GT)
            avd_base = relativeAbsoluteVolumeDifference(base_P, base_GT)
            [hausdorff_base, avgDist_base] = getBoundaryDistances(base_P, base_GT)

            csvwriter.writerow(
                ['Case' + str(i), dice_apex, dice_mid, dice_base, avd_apex, avd_mid, avd_base, hausdorff_apex,
                 hausdorff_mid, hausdorff_base, avgDist_apex, avgDist_mid, avgDist_base])

            print(i)


def thresholdArray(array, threshold):
    # threshold image
    array[array < threshold] = 0
    array[array >= threshold] = 1
    array = np.asarray(array, np.int16)

    return array


def removeSegmentationsInImagePaddedRegion(array_test, array_pred):
    for i in range(0, array_test.shape[0]):
        if np.count_nonzero(array_test[i, :, :, 0]) == 0:
            array_pred[:, i, :, :] = 0


def getConnectedComponents(predictionImage):
    pred_img = utils.castImage(predictionImage, sitk.sitkInt8)
    pred_img_cc = utils.getLargestConnectedComponents(pred_img)
    pred_img_cc = utils.castImage(pred_img_cc, sitk.sitkInt8)

    img_isl = sitk.Subtract(pred_img, pred_img_cc)

    return pred_img_cc, img_isl


def removeIslands(predictedArray):
    pred = predictedArray
    print(pred.shape)
    pred_pz = thresholdArray(pred[0, :, :, :], 0.5)
    pred_cz = thresholdArray(pred[1, :, :, :], 0.5)
    pred_us = thresholdArray(pred[2, :, :, :], 0.5)
    pred_afs = thresholdArray(pred[3, :, :, :], 0.5)
    pred_bg = thresholdArray(pred[4, :, :, :], 0.5)

    pred_pz_img = sitk.GetImageFromArray(pred_pz)
    pred_cz_img = sitk.GetImageFromArray(pred_cz)
    pred_us_img = sitk.GetImageFromArray(pred_us)
    pred_afs_img = sitk.GetImageFromArray(pred_afs)
    pred_bg_img = sitk.GetImageFromArray(pred_bg)
    # pred_bg_img = utils.castImage(pred_bg, sitk.sitkInt8)

    pred_pz_img_cc, pz_otherCC = getConnectedComponents(pred_pz_img)
    pred_cz_img_cc, cz_otherCC = getConnectedComponents(pred_cz_img)
    pred_us_img_cc, us_otherCC = getConnectedComponents(pred_us_img)
    pred_afs_img_cc, afs_otherCC = getConnectedComponents(pred_afs_img)
    pred_bg_img_cc, bg_otherCC = getConnectedComponents(pred_bg_img)

    added_otherCC = sitk.Add(afs_otherCC, pz_otherCC)
    added_otherCC = sitk.Add(added_otherCC, cz_otherCC)
    added_otherCC = sitk.Add(added_otherCC, us_otherCC)
    added_otherCC = sitk.Add(added_otherCC, bg_otherCC)

    # sitk.WriteImage(added_otherCC, 'addedOtherCC.nrrd')
    # sitk.WriteImage(pred_cz_img, 'pred_cz.nrrd')

    pz_dis = sitk.SignedMaurerDistanceMap(pred_pz_img_cc, insideIsPositive=True, squaredDistance=False,
                                          useImageSpacing=False)
    cz_dis = sitk.SignedMaurerDistanceMap(pred_cz_img_cc, insideIsPositive=True, squaredDistance=False,
                                          useImageSpacing=False)
    us_dis = sitk.SignedMaurerDistanceMap(pred_us_img_cc, insideIsPositive=True, squaredDistance=False,
                                          useImageSpacing=False)
    afs_dis = sitk.SignedMaurerDistanceMap(pred_afs_img_cc, insideIsPositive=True, squaredDistance=False,
                                           useImageSpacing=False)
    bg_dis = sitk.SignedMaurerDistanceMap(pred_bg_img_cc, insideIsPositive=True, squaredDistance=False,
                                          useImageSpacing=False)

    # sitk.WriteImage(pred_cz_img_cc, 'pred_cz_cc.nrrd')
    # sitk.WriteImage(cz_dis, 'cz_dis.nrrd')

    array_pz = sitk.GetArrayFromImage(pred_pz_img_cc)
    array_cz = sitk.GetArrayFromImage(pred_cz_img_cc)
    array_us = sitk.GetArrayFromImage(pred_us_img_cc)
    array_afs = sitk.GetArrayFromImage(pred_afs_img_cc)
    array_bg = sitk.GetArrayFromImage(pred_bg_img_cc)

    finalPrediction = np.zeros([5, 32, 168, 168])
    finalPrediction[0] = array_pz
    finalPrediction[1] = array_cz
    finalPrediction[2] = array_us
    finalPrediction[3] = array_afs
    finalPrediction[4] = array_bg

    array = np.zeros([1, 1, 1, 1])

    for x in range(0, pred_cz_img.GetSize()[0]):
        for y in range(0, pred_cz_img.GetSize()[1]):
            for z in range(0, pred_cz_img.GetSize()[2]):

                pos = [x, y, z]
                if (added_otherCC[pos] > 0):
                    # print(pz_dis.GetPixel(x,y,z),cz_dis.GetPixel(x,y,z),us_dis.GetPixel(x,y,z), afs_dis.GetPixel(x,y,z))
                    array = [pz_dis.GetPixel(x, y, z), cz_dis.GetPixel(x, y, z), us_dis.GetPixel(x, y, z),
                             afs_dis.GetPixel(x, y, z), bg_dis.GetPixel(x, y, z)]
                    maxValue = max(array)
                    max_index = array.index(maxValue)
                    finalPrediction[max_index, z, y, x] = 1

    return finalPrediction


def postprocesAndEvaluateFiles(name, GT_array, csvName):
    prediction = np.load(name + '.npy')
    print(GT_array.shape)
    print(prediction.shape)

    outDir = name[:-3] + '/'
    if not os.path.exists(outDir):
        os.makedirs(outDir)

    for i in range(0, prediction.shape[1]):
        print(i)
        array = removeIslands(prediction[:, i, :, :, :])
        # print('preditction', prediction.shape)
        # array = prediction[:, i, :, :, :]
        np.save(outDir + 'predicted_' + str(i), array)

    evaluateFiles_zones(GT_array, pred_directory=outDir, csvName=csvName)


if __name__ == '__main__':
    name = 'predicted_UNet_zones_Fold1_LR_0.0005_final'
    GT_array_name = 'drive/My Drive/prostrate/final_test_array_GT.npy'
    csvName = 'evaluation_sad.csv'
    GT_array = np.load(GT_array_name)

    # weights epochs LR gpu_id dist orient prediction LRDecay earlyStop
    postprocesAndEvaluateFiles(name, GT_array, csvName)
# Out:
# Requirement already satisfied: SimpleITK in /usr/local/lib/python3.6/dist-packages (1.2.0)
# (20, 32, 168, 168, 5)
# (5, 20, 32, 168, 168)
# 0
# (5, 32, 168, 168)
# 1
# (5, 32, 168, 168)
# 2
# (5, 32, 168, 168)
# 3
# (5, 32, 168, 168)
# 4
# (5, 32, 168, 168)
# 5
# (5, 32, 168, 168)
# 6
# (5, 32, 168, 168)
# 7
# (5, 32, 168, 168)
# 8
# (5, 32, 168, 168)
# 9
# (5, 32, 168, 168)
# 10
# (5, 32, 168, 168)
# 11
# (5, 32, 168, 168)
# 12
# (5, 32, 168, 168)
# 13
# (5, 32, 168, 168)
# 14
# (5, 32, 168, 168)
# 15
# (5, 32, 168, 168)
# 16
# (5, 32, 168, 168)
# 17
# (5, 32, 168, 168)
# 18
# (5, 32, 168, 168)
# 19
# (5, 32, 168, 168)
# (20, 4)
# Case0
# 0.8066826996878678
# 0.8188700831118141
# 0.6883160361566789
# 0.5596961784951341
# Case1
# 0.6894690573058287
# 0.8872335563091025
# 0.6938394523957685
# 0.38319783197831975
# Case2
# 0.7647625398236646
# 0.7454995054401583
# 0.5904821540388228
# 0.3126050420168067
# Case3
# 0.7662292125826486
# 0.883408119772535
# 0.6986016066646831
# 0.4259534422981674
# Case4
# 0.7733268367382452
# 0.9172325132939871
# 0.7919923736892278
# 0.35330836454431963
# Case5
# 0.8544139291641876
# 0.8665952210843852
# 0.5999129299085764
# 0.5703787450537027
# Case6
# 0.7795302139137602
# 0.7852642632131607
# 0.6435816719132564
# 0.5028192371475954
# Case7
# 0.7181665045434056
# 0.878922481730907
# 0.7444395987788923
# 0.3763132760267431
# Case8
# 0.8122004357298476
# 0.887688065584692
# 0.7370114942528736
# 0.2548494983277592
# Case9
# 0.7159568666772214
# 0.8726483357452967
# 0.502283105022831
# 0.42393162393162387
# Case10
# 0.6571109817617385
# 0.9139835952169186
# 0.7380600689315607
# 0.060968660968660965
# Case11
# 0.7485999011694944
# 0.9394461839271795
# 0.0
# 0.2992284468299229
# Case12
# 0.6361984322872875
# 0.7331058536155425
# 0.01690701143709597
# 0.23608174770965468
# Case13
# 0.4917347520425613
# 0.8826946887202768
# 0.07377049180327869
# 0.11699271192942079
# Case14
# 0.7811585450829192
# 0.707841920132423
# 0.7095300261096605
# 0.3943760984182777
# Case15
# 0.6578707916287534
# 0.8871648887915663
# 0.5867589787970575
# 0.2926350245499182
# Case16
# 0.8189788189086827
# 0.9142141438826943
# 0.7681647940074906
# 0.15727272727272726
# Case17
# 0.8074292610969559
# 0.9135227411291306
# 0.2011764705882353
# 0.28227571115973743
# Case18
# 0.6835390946502058
# 0.7894579573298274
# 0.7757547822078821
# 0.4204875866696489
# Case19
# 0.7477598566308244
# 0.8563719957052005
# 0.7744717550668392
# 0.45910729137787637
# Dices
# 0.735556
# 0.8540584
# 0.56675273
# 0.34412396
# Mean Dist
# 1.5416688
# 1.1750753
# 1.7234112
# 4.726535
